# %% [markdown]
# # AFCON 2023 project

# %%
import pandas as pd
from string import ascii_uppercase as alphabet
import pickle
from bs4 import BeautifulSoup # to parse HTML or XML documents and extract data 
import requests # to aend requests to the website (wikipedia) that I am going to scrape

# %% [markdown]
# # Scraping data from the internet relating to AFCON 2023/24

# %%
all_group_tables = pd.read_html('https://en.wikipedia.org/wiki/2023_Africa_Cup_of_Nations')

# %%
all_group_tables
# Out:
# [   Coupe d'Afrique des Nations 2023 Coupe d'Afrique des Nations 2023.1
#  0                  Official logo[1]                   Official logo[1]
#  1                Tournament details                 Tournament details
#  2                      Host country                        Ivory Coast
#  3                             Dates      13 January – 11 February 2024
#  4                             Teams                                 24
#  5                          Venue(s)               6 (in 5 host cities)
#  6                   Final positions                    Final positions
#  7                         Champions            Ivory Coast (3rd title)
#  8                        Runners-up                            Nigeria
#  9                       Third place                       South Africa
#  10                     Fourth place                           DR Congo
#  11            Tournament statistics              Tournament statistics
#  12                   Matches played                                 52
#  13                     Goals scored               119 (2.29 per match)
#  14                       Attendance       1,109,593 (21,338 per match)
#  15                    Top scorer(s)               Emilio Nsue(5 goals)
#  16                   Best player(s)               William Troost-Ekong
#  17                Best young player                      Simon Adingra
#  18                  Best goalkeeper                    Ronwen Williams
#  19                  Fair play award                       South Africa
#  20                    ← 2021 2025 →                      ← 2021 2025 →,
#                                     Title sponsor  \
#  0    TotalEnergies 1XBET Rexona Visa Puma Orange
#  1                     TotalEnergies 1XBET Rexona
#  2  Air Côte d'Ivoire[17] Apsonic[18] Ecobank[19]
#  3                             Celeste Porteo[21]
#
#                                     Official sponsors  \
#  0  Air Côte d'Ivoire[17] Apsonic[18] Ecobank[19] ...
#  1                                   Visa Puma Orange
#  2                                    Razzl Tecno[20]
#  3                  LONACI[22] Smart Technologies[23]
#
#                                     National sponsors
#  0  Celeste Porteo[21] LONACI[22] Smart Technologi...
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN  ,
#                              0                 1
#  0  TotalEnergies 1XBET Rexona  Visa Puma Orange,
#                                                 0                1
#  0  Air Côte d'Ivoire[17] Apsonic[18] Ecobank[19]  Razzl Tecno[20],
#                      0                                  1
#  0  Celeste Porteo[21]  LONACI[22] Smart Technologies[23],
#                   Team      Method ofqualification Date ofqualification  \
#  0         Ivory Coast  Hosts / Group H runners-up      30 January 2019
#  1             Morocco             Group K winners        24 March 2023
#  2             Algeria             Group F winners        27 March 2023
#  3        South Africa          Group K runners-up        28 March 2023
#  4             Senegal             Group L winners        28 March 2023
#  5        Burkina Faso             Group B winners        28 March 2023
#  6             Tunisia             Group J winners        28 March 2023
#  7               Egypt             Group D winners         14 June 2023
#  8              Zambia             Group H winners         17 June 2023
#  9   Equatorial Guinea          Group J runners-up         17 June 2023
#  10            Nigeria             Group A winners         18 June 2023
#  11      Guinea-Bissau          Group A runners-up         18 June 2023
#  12         Cape Verde          Group B runners-up         18 June 2023
#  13               Mali             Group G winners         18 June 2023
#  14             Guinea          Group D runners-up         20 June 2023
#  15              Ghana             Group E winners     7 September 2023
#  16             Angola          Group E runners-up     7 September 2023
#  17           Tanzania          Group F runners-up     7 September 2023
#  18         Mozambique          Group L runners-up     9 September 2023
#  19           DR Congo             Group I winners     9 September 2023
#  20         Mauritania          Group I runners-up     9 September 2023
#  21             Gambia          Group G runners-up    10 September 2023
#  22           Cameroon             Group C winners    12 September 2023
#  23            Namibia          Group C runners-up    12 September 2023
#
#     Finalsappearance  Lastappearance  \
#  0              25th            2021
#  1              19th            2021
#  2              20th            2021
#  3              11th            2019
#  4              17th            2021
#  5              13th            2021
#  6              21st            2021
#  7              26th            2021
#  8              18th            2015
#  9               4th            2021
#  10             20th            2021
#  11              4th            2021
#  12              4th            2021
#  13             13th            2021
#  14             14th            2021
#  15             24th            2021
#  16              9th            2019
#  17              3rd            2019
#  18              5th            2010
#  19             20th            2019
#  20              3rd            2021
#  21              2nd            2021
#  22             21st            2021
#  23              4th            2019
#
#                               Previous bestperformance
#  0                              Champions (1992, 2015)
#  1                                    Champions (1976)
#  2                              Champions (1990, 2019)
#  3                                    Champions (1996)
#  4                                    Champions (2021)
#  5                                   Runners-up (2013)
#  6                                    Champions (2004)
#  7   Champions (1957, 1959, 1986, 1998, 2006, 2008,...
#  8                                    Champions (2012)
#  9                                 Fourth place (2015)
#  10                       Champions (1980, 1994, 2013)
#  11                     Group stage (2017, 2019, 2021)
#  12                              Quarter-finals (2013)
#  13                                  Runners-up (1972)
#  14                                  Runners-up (1976)
#  15                 Champions (1963, 1965, 1978, 1982)
#  16                        Quarter-finals (2008, 2010)
#  17                           Group stage (1980, 2019)
#  18               Group stage (1986, 1996, 1998, 2010)
#  19                             Champions (1968, 1974)
#  20                           Group stage (2019, 2021)
#  21                              Quarter-finals (2021)
#  22           Champions (1984, 1988, 2000, 2002, 2017)
#  23                     Group stage (1998, 2008, 2019)  ,
#     Number of stadiums  Capacity(Minimum)
#  0                   2              40000
#  1                   2              20000
#  2                   2              15000,
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan-PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)  \
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan-PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan-PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan-PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan-PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan-PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan-PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan-PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#  0                          Alassane Ouattara Stadium
#  1                                   Capacity: 60,000
#  2                                                NaN
#  3                                            Korhogo
#  4                       Amadou Gon Coulibaly Stadium
#  5                                   Capacity: 20,000
#  6                                                NaN
#
#                            Abidjan                               \
#                 Unnamed: 1_level_1           Unnamed: 2_level_1
#                 Unnamed: 1_level_2           Unnamed: 2_level_2
#                 Unnamed: 1_level_3           Unnamed: 2_level_3
#                 Unnamed: 1_level_4           Unnamed: 2_level_4
#                 Unnamed: 1_level_5           Unnamed: 2_level_5
#                 Unnamed: 1_level_6           Unnamed: 2_level_6
#                 Unnamed: 1_level_7           Unnamed: 2_level_7
#  0  Felix Houphouet Boigny Stadium             Stade de la Paix
#  1            Capacity: 33,000[34]             Capacity: 40,000
#  2                             NaN                          NaN
#  3                       San-Pédro                 Yamoussoukro
#  4           Laurent Pokou Stadium  Charles Konan Banny Stadium
#  5                Capacity: 20,000             Capacity: 20,000
#  6                             NaN                          NaN
#
#                Bouaké
#    Unnamed: 3_level_1
#    Unnamed: 3_level_2
#    Unnamed: 3_level_3
#    Unnamed: 3_level_4
#    Unnamed: 3_level_5
#    Unnamed: 3_level_6
#    Unnamed: 3_level_7
#  0                NaN
#  1                NaN
#  2                NaN
#  3                NaN
#  4                NaN
#  5                NaN
#  6                NaN  ,
#      0                                                  1
#  0 NaN  This section does not cite any sources. Please...,
#                                                 Pot 1  \
#  0  Ivory Coast (50) (hosts) Morocco (13) Senegal ...
#
#                                                 Pot 2  \
#  0  Nigeria (40) Cameroon (41) Mali (49) Burkina F...
#
#                                                 Pot 3  \
#  0  South Africa (65) Cape Verde (71) Guinea (81) ...
#
#                                                 Pot 4
#  0  Guinea-Bissau (106) Mozambique (113) Namibia (...  ,
#     Pos  \
#  0    1
#  1    2
#  2    3
#  3    4
#
#    Team.mw-parser-output .hlist dl,.mw-parser-output .hlist ol,.mw-parser-output .hlist ul{margin:0;padding:0}.mw-parser-output .hlist dd,.mw-parser-output .hlist dt,.mw-parser-output .hlist li{margin:0;display:inline}.mw-parser-output .hlist.inline,.mw-parser-output .hlist.inline dl,.mw-parser-output .hlist.inline ol,.mw-parser-output .hlist.inline ul,.mw-parser-output .hlist dl dl,.mw-parser-output .hlist dl ol,.mw-parser-output .hlist dl ul,.mw-parser-output .hlist ol dl,.mw-parser-output .hlist ol ol,.mw-parser-output .hlist ol ul,.mw-parser-output .hlist ul dl,.mw-parser-output .hlist ul ol,.mw-parser-output .hlist ul ul{display:inline}.mw-parser-output .hlist .mw-empty-li{display:none}.mw-parser-output .hlist dt::after{content:": "}.mw-parser-output .hlist dd::after,.mw-parser-output .hlist li::after{content:" · ";font-weight:bold}.mw-parser-output .hlist dd:last-child::after,.mw-parser-output .hlist dt:last-child::after,.mw-parser-output .hlist li:last-child::after{content:none}.mw-parser-output .hlist dd dd:first-child::before,.mw-parser-output .hlist dd dt:first-child::before,.mw-parser-output .hlist dd li:first-child::before,.mw-parser-output .hlist dt dd:first-child::before,.mw-parser-output .hlist dt dt:first-child::before,.mw-parser-output .hlist dt li:first-child::before,.mw-parser-output .hlist li dd:first-child::before,.mw-parser-output .hlist li dt:first-child::before,.mw-parser-output .hlist li li:first-child::before{content:" (";font-weight:normal}.mw-parser-output .hlist dd dd:last-child::after,.mw-parser-output .hlist dd dt:last-child::after,.mw-parser-output .hlist dd li:last-child::after,.mw-parser-output .hlist dt dd:last-child::after,.mw-parser-output .hlist dt dt:last-child::after,.mw-parser-output .hlist dt li:last-child::after,.mw-parser-output .hlist li dd:last-child::after,.mw-parser-output .hlist li dt:last-child::after,.mw-parser-output .hlist li li:last-child::after{content:")";font-weight:normal}.mw-parser-output .hlist ol{counter-reset:listitem}.mw-parser-output .hlist ol>li{counter-increment:listitem}.mw-parser-output .hlist ol>li::before{content:" "counter(listitem)"\a0 "}.mw-parser-output .hlist dd ol>li:first-child::before,.mw-parser-output .hlist dt ol>li:first-child::before,.mw-parser-output .hlist li ol>li:first-child::before{content:" ("counter(listitem)"\a0 "}.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte  \
#  0                                  Equatorial Guinea
#  1                                            Nigeria
#  2                                    Ivory Coast (H)
#  3                                      Guinea-Bissau
#
#     Pld  W  D  L  GF  GA  GD   Pts              Qualification
#  0    3  2  1  0   9   3  +6  7[a]  Advance to knockout stage
#  1    3  2  1  0   3   1  +2  7[a]  Advance to knockout stage
#  2    3  1  0  2   2   5  −3     3  Advance to knockout stage
#  3    3  0  0  3   2   7  −5     0                        NaN  ,
#                                           Ivory Coast     2–0  Guinea-Bissau
#  0  .mw-parser-output .plainlist ol,.mw-parser-out...  Report            NaN,
#         Nigeria     1–1 Equatorial Guinea
#  0  Osimhen 38'  Report      Salvador 36',
#                  Equatorial Guinea     4–2                      Guinea-Bissau
#  0  Nsue 21', 51', 61' Miranda 46'  Report  Esteban 37' (o.g.) Zé Turbo 90+3',
#     Ivory Coast     0–1                  Nigeria
#  0          NaN  Report  Troost-Ekong 55' (pen.),
#                     Equatorial Guinea     4–0  Ivory Coast
#  0  Nsue 42', 75' Ganet 73' Buyla 88'  Report          NaN,
#     Guinea-Bissau     0–1              Nigeria
#  0            NaN  Report  Sanganté 36' (o.g.),
#     Pos     Teamvte  Pld  W  D  L  GF  GA  GD   Pts              Qualification
#  0    1  Cape Verde    3  2  1  0   7   3  +4     7  Advance to knockout stage
#  1    2       Egypt    3  0  3  0   6   6   0     3  Advance to knockout stage
#  2    3       Ghana    3  0  2  1   5   6  −1  2[a]                        NaN
#  3    4  Mozambique    3  0  2  1   4   7  −3  2[a]                        NaN,
#                             Egypt     2–2           Mozambique
#  0  Mohamed 2' Salah 90+7' (pen.)  Report  Witi 55' Clésio 58',
#         Ghana     1–2                    Cape Verde
#  0  Djiku 56'  Report  Monteiro 17' Rodrigues 90+2',
#                        Egypt     2–2             Ghana
#  0  Marmoush 69' Mohamed 74'  Report  Kudus 45+3', 71',
#                       Cape Verde     3–0  Mozambique
#  0  Bebé 32' Mendes 51' Pina 69'  Report         NaN,
#                          Mozambique     2–2                           Ghana
#  0  Geny 90+1' (pen.) Mandava 90+4'  Report  J. Ayew 15' (pen.), 70' (pen.),
#                          Cape Verde     2–2                        Egypt
#  0  G. Tavares 45+1' Teixeira 90+9'  Report  Trézéguet 50' Mohamed 90+3',
#     Pos   Teamvte  Pld  W  D  L  GF  GA  GD   Pts              Qualification
#  0    1   Senegal    3  3  0  0   8   1  +7     9  Advance to knockout stage
#  1    2  Cameroon    3  1  1  1   5   6  −1  4[a]  Advance to knockout stage
#  2    3    Guinea    3  1  1  1   2   3  −1  4[a]  Advance to knockout stage
#  3    4    Gambia    3  0  0  3   2   7  −5     0                        NaN,
#                         Senegal     3–0  Gambia
#  0  P. Gueye 4' Camara 52', 86'  Report     NaN,
#      Cameroon     1–1    Guinea
#  0  Magri 51'  Report  Bayo 10',
#                                  Senegal     3–1         Cameroon
#  0  I. Sarr 16' H. Diallo 71' Mané 90+5'  Report  Castelletto 83',
#            Guinea     1–0  Gambia
#  0  A. Camara 69'  Report     NaN,
#     Guinea     0–2                 Senegal
#  0     NaN  Report  Seck 61' I. Ndiaye 90',
#                       Gambia     2–3  \
#  0  Jallow 72' E. Colley 85'  Report
#
#                                        Cameroon
#  0  Toko Ekambi 56' Gomez 87' (o.g.) Wooh 90+1'  ,
#     Pos       Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1        Angola    3  2  1  0   6   3  +3    7  Advance to knockout stage
#  1    2  Burkina Faso    3  1  1  1   3   4  −1    4  Advance to knockout stage
#  2    3    Mauritania    3  1  0  2   3   4  −1    3  Advance to knockout stage
#  3    4       Algeria    3  0  2  1   3   4  −1    2                        NaN,
#           Algeria     1–1               Angola
#  0  Bounedjah 18'  Report  Mabululu 68' (pen.),
#            Burkina Faso     1–0  Mauritania
#  0  Traoré 90+6' (pen.)  Report         NaN,
#                  Algeria     2–2                       Burkina Faso
#  0  Bounedjah 51', 90+5'  Report  M. Konaté 45+3' Traoré 71' (pen.),
#             Mauritania     2–3                      Angola
#  0  Amar 43' Koita 58'  Report  Dala 30', 50' Gilberto 53',
#                      Angola     2–0  Burkina Faso
#  0  Mabululu 36' Zini 90+2'  Report           NaN,
#    Mauritania     1–0  Algeria
#  0   Yali 37'  Report      NaN,
#     Pos       Teamvte  Pld  W  D  L  GF  GA  GD   Pts  \
#  0    1          Mali    3  1  2  0   3   1  +2     5
#  1    2  South Africa    3  1  1  1   4   2  +2  4[a]
#  2    3       Namibia    3  1  1  1   1   4  −3  4[a]
#  3    4       Tunisia    3  0  2  1   1   2  −1     2
#
#                 Qualification
#  0  Advance to knockout stage
#  1  Advance to knockout stage
#  2  Advance to knockout stage
#  3                        NaN  ,
#     Tunisia     0–1    Namibia
#  0      NaN  Report  Hotto 88',
#                           Mali     2–0  South Africa
#  0  H. Traoré 60' Sinayoko 66'  Report           NaN,
#       Tunisia     1–1          Mali
#  0  Rafia 20'  Report  Sinayoko 10',
#                                 South Africa     4–0  Namibia
#  0  Tau 14' (pen.) Zwane 25', 40' Maseko 75'  Report      NaN,
#     South Africa     0–0  Tunisia
#  0           NaN  Report      NaN,
#     Namibia     0–0  Mali
#  0      NaN  Report   NaN,
#     Pos   Teamvte  Pld  W  D  L  GF  GA  GD   Pts              Qualification
#  0    1   Morocco    3  2  1  0   5   1  +4     7  Advance to knockout stage
#  1    2  DR Congo    3  0  3  0   2   2   0     3  Advance to knockout stage
#  2    3    Zambia    3  0  2  1   2   3  −1  2[a]                        NaN
#  3    4  Tanzania    3  0  2  1   1   4  −3  2[a]                        NaN,
#                                Morocco     3–0  Tanzania
#  0  Saïss 30' Ounahi 77' En-Nesyri 80'  Report       NaN,
#      DR Congo     1–1      Zambia
#  0  Wissa 27'  Report  Kangwa 23',
#       Morocco     1–1   DR Congo
#  0  Hakimi 6'  Report  Silas 76',
#       Zambia     1–1   Tanzania
#  0  Daka 88'  Report  Msuva 11',
#     Tanzania     0–0  DR Congo
#  0       NaN  Report       NaN,
#     Zambia     0–1     Morocco
#  0     NaN  Report  Ziyech 37',
#     Pos Grp          Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
#  0    1   C           Guinea    3  1  1  1   2   3  −1    4
#  1    2   E          Namibia    3  1  1  1   1   4  −3    4
#  2    3   D       Mauritania    3  1  0  2   3   4  −1    3
#  3    4   A  Ivory Coast (H)    3  1  0  2   2   5  −3    3
#  4    5   B            Ghana    3  0  2  1   5   6  −1    2
#  5    6   F           Zambia    3  0  2  1   2   3  −1    2
#
#                 Qualification
#  0  Advance to knockout stage
#  1  Advance to knockout stage
#  2  Advance to knockout stage
#  3  Advance to knockout stage
#  4                        NaN
#  5                        NaN  ,
#      0                                        1   \
#  0  NaN                              Round of 16
#  1  NaN                                      NaN
#  2  NaN  27 January – Abidjan (Houphouet Boigny)
#  3  NaN  27 January – Abidjan (Houphouet Boigny)
#  4  NaN                                  Nigeria
#  5  NaN                                  Nigeria
#  6  NaN                                 Cameroon
#  7  NaN                                 Cameroon
#  8  NaN                      27 January – Bouaké
#  9  NaN                      27 January – Bouaké
#  10 NaN                                   Angola
#  11 NaN                                   Angola
#  12 NaN                                  Namibia
#  13 NaN                                  Namibia
#  14 NaN  29 January – Abidjan (Houphouet Boigny)
#  15 NaN  29 January – Abidjan (Houphouet Boigny)
#  16 NaN                               Cape Verde
#  17 NaN                               Cape Verde
#  18 NaN                               Mauritania
#  19 NaN                               Mauritania
#  20 NaN                   30 January – San Pédro
#  21 NaN                   30 January – San Pédro
#  22 NaN                                  Morocco
#  23 NaN                                  Morocco
#  24 NaN                             South Africa
#  25 NaN                             South Africa
#  26 NaN                     30 January – Korhogo
#  27 NaN                     30 January – Korhogo
#  28 NaN                                     Mali
#  29 NaN                                     Mali
#  30 NaN                             Burkina Faso
#  31 NaN                             Burkina Faso
#  32 NaN                29 January – Yamoussoukro
#  33 NaN                29 January – Yamoussoukro
#  34 NaN                                  Senegal
#  35 NaN                                  Senegal
#  36 NaN                          Ivory Coast (p)
#  37 NaN                          Ivory Coast (p)
#  38 NaN                   28 January – San Pédro
#  39 NaN                   28 January – San Pédro
#  40 NaN                                    Egypt
#  41 NaN                                    Egypt
#  42 NaN                             DR Congo (p)
#  43 NaN                             DR Congo (p)
#  44 NaN          28 January – Abidjan (Ouattara)
#  45 NaN          28 January – Abidjan (Ouattara)
#  46 NaN                        Equatorial Guinea
#  47 NaN                        Equatorial Guinea
#  48 NaN                                   Guinea
#  49 NaN                                   Guinea
#  50 NaN                                      NaN
#  51 NaN                                      NaN
#  52 NaN                                      NaN
#  53 NaN                                      NaN
#  54 NaN                                      NaN
#  55 NaN                                      NaN
#  56 NaN                                      NaN
#  57 NaN                                      NaN
#  58 NaN                                      NaN
#
#                                           2   3   4   \
#  0                               Round of 16 NaN NaN
#  1                                       NaN NaN NaN
#  2   27 January – Abidjan (Houphouet Boigny) NaN NaN
#  3   27 January – Abidjan (Houphouet Boigny) NaN NaN
#  4                                         2 NaN NaN
#  5                                         2 NaN NaN
#  6                                         0 NaN NaN
#  7                                         0 NaN NaN
#  8                       27 January – Bouaké NaN NaN
#  9                       27 January – Bouaké NaN NaN
#  10                                        3 NaN NaN
#  11                                        3 NaN NaN
#  12                                        0 NaN NaN
#  13                                        0 NaN NaN
#  14  29 January – Abidjan (Houphouet Boigny) NaN NaN
#  15  29 January – Abidjan (Houphouet Boigny) NaN NaN
#  16                                        1 NaN NaN
#  17                                        1 NaN NaN
#  18                                        0 NaN NaN
#  19                                        0 NaN NaN
#  20                   30 January – San Pédro NaN NaN
#  21                   30 January – San Pédro NaN NaN
#  22                                        0 NaN NaN
#  23                                        0 NaN NaN
#  24                                        2 NaN NaN
#  25                                        2 NaN NaN
#  26                     30 January – Korhogo NaN NaN
#  27                     30 January – Korhogo NaN NaN
#  28                                        2 NaN NaN
#  29                                        2 NaN NaN
#  30                                        1 NaN NaN
#  31                                        1 NaN NaN
#  32                29 January – Yamoussoukro NaN NaN
#  33                29 January – Yamoussoukro NaN NaN
#  34                                    1 (4) NaN NaN
#  35                                    1 (4) NaN NaN
#  36                                    1 (5) NaN NaN
#  37                                    1 (5) NaN NaN
# ...
#  16     Suspension to be served outside the tournament
#  17           Semi-final vs DR Congo (7 February 2024)
#  18           Semi-final vs DR Congo (7 February 2024)
#  19           Semi-final vs DR Congo (7 February 2024)
#  20           Semi-final vs DR Congo (7 February 2024)
#  21     Suspension to be served outside the tournament
#  22     Suspension to be served outside the tournament  ,
#                          0                      1     2
#  0  Man of the Competition   William Troost-Ekong  [96]
#  1             Golden Boot  Emilio Nsue (5 goals)  [96]
#  2         Best Goalkeeper        Ronwen Williams  [96]
#  3       Best Young Player          Simon Adingra   NaN
#  4          Fair Play team           South Africa  [96],
#          Goalkeeper                                          Defenders  \
#  0  Ronwen Williams  Ola Aina Ghislain Konan William Troost-Ekong C...
#
#                                        Midfielders  \
#  0  Teboho Mokoena Jean Michaël Seri Franck Kessié
#
#                                    Forwards       Coach
#  0  Yoane Wissa Ademola Lookman Emilio Nsue  Emerse Faé  ,
#                                  0                            1  \
#  0  Champion Runner-up Third place  Fourth place Quarter-finals
#
#                           2
#  0  Round of 16 Group stage  ,
#                                  Pos.                              Team  \
#  0                                  1                       Ivory Coast
#  1                                  2                           Nigeria
#  2                                  3                      South Africa
#  3                                  4                          DR Congo
#  4   Eliminated in the quarter-finals  Eliminated in the quarter-finals
#  5                                  5                        Cape Verde
#  6                                  8                            Angola
#  7                                  6                              Mali
#  8                                  7                            Guinea
#  9      Eliminated in the round of 16     Eliminated in the round of 16
#  10                                 9                           Senegal
#  11                                10                 Equatorial Guinea
#  12                                11                           Morocco
#  13                                12                             Egypt
#  14                                13                      Burkina Faso
#  15                                14                          Cameroon
#  16                                15                           Namibia
#  17                                16                        Mauritania
#  18     Eliminated in the group stage     Eliminated in the group stage
#  19                                17                             Ghana
#  20                                18                           Algeria
#  21                                19                            Zambia
#  22                                20                           Tunisia
#  23                                21                        Mozambique
#  24                                22                          Tanzania
#  25                                23                     Guinea-Bissau
#  26                                24                            Gambia
#
#                                     G                               Pld  \
#  0                                  A                                 7
#  1                                  A                                 7
#  2                                  E                                 7
#  3                                  F                                 7
#  4   Eliminated in the quarter-finals  Eliminated in the quarter-finals
#  5                                  B                                 5
#  6                                  D                                 5
#  7                                  E                                 5
#  8                                  C                                 5
#  9      Eliminated in the round of 16     Eliminated in the round of 16
#  10                                 C                                 4
#  11                                 A                                 4
#  12                                 F                                 4
#  13                                 B                                 4
#  14                                 D                                 4
#  15                                 C                                 4
#  16                                 E                                 4
#  17                                 D                                 4
#  18     Eliminated in the group stage     Eliminated in the group stage
#  19                                 B                                 3
#  20                                 D                                 3
#  21                                 F                                 3
#  22                                 E                                 3
#  23                                 B                                 3
#  24                                 F                                 3
#  25                                 A                                 3
#  26                                 C                                 3
#
#                                     W                                 D  \
#  0                                  4                                 1
#  1                                  4                                 2
#  2                                  2                                 4
#  3                                  1                                 5
#  4   Eliminated in the quarter-finals  Eliminated in the quarter-finals
#  5                                  3                                 2
#  6                                  3                                 1
#  7                                  2                                 2
#  8                                  2                                 1
#  9      Eliminated in the round of 16     Eliminated in the round of 16
#  10                                 3                                 1
#  11                                 2                                 1
#  12                                 2                                 1
#  13                                 0                                 4
#  14                                 1                                 1
#  15                                 1                                 1
#  16                                 1                                 1
#  17                                 1                                 0
#  18     Eliminated in the group stage     Eliminated in the group stage
#  19                                 0                                 2
#  20                                 0                                 2
#  21                                 0                                 2
#  22                                 0                                 2
#  23                                 0                                 2
#  24                                 0                                 2
#  25                                 0                                 0
#  26                                 0                                 0
#
#                                     L                               Pts  \
#  0                                  2                                13
#  1                                  1                                14
#  2                                  1                                10
#  3                                  1                                 8
#  4   Eliminated in the quarter-finals  Eliminated in the quarter-finals
#  5                                  0                                11
#  6                                  1                                10
#  7                                  1                                 8
#  8                                  2                                 7
#  9      Eliminated in the round of 16     Eliminated in the round of 16
#  10                                 0                                10
#  11                                 1                                 7
#  12                                 1                                 7
#  13                                 0                                 4
#  14                                 2                                 4
#  15                                 2                                 4
#  16                                 2                                 4
#  17                                 3                                 3
#  18     Eliminated in the group stage     Eliminated in the group stage
#  19                                 1                                 2
#  20                                 1                                 2
#  21                                 1                                 2
#  22                                 1                                 2
#  23                                 1                                 2
#  24                                 1                                 2
#  25                                 3                                 0
#  26                                 3                                 0
#
#                                    GF                                GA  \
#  0                                  8                                 8
#  1                                  8                                 4
#  2                                  7                                 3
#  3                                  6                                 5
#  4   Eliminated in the quarter-finals  Eliminated in the quarter-finals
#  5                                  8                                 3
#  6                                  9                                 4
#  7                                  6                                 4
#  8                                  4                                 6
#  9      Eliminated in the round of 16     Eliminated in the round of 16
#  10                                 9                                 2
#  11                                 9                                 4
#  12                                 5                                 3
#  13                                 7                                 7
#  14                                 4                                 6
#  15                                 5                                 8
#  16                                 1                                 7
#  17                                 3                                 5
#  18     Eliminated in the group stage     Eliminated in the group stage
#  19                                 5                                 6
#  20                                 3                                 4
#  21                                 2                                 3
#  22                                 1                                 2
#  23                                 4                                 7
#  24                                 1                                 4
#  25                                 2                                 7
#  26                                 2                                 7
#
#                                    GD
#  0                                  0
#  1                                 +4
#  2                                 +4
#  3                                 +1
#  4   Eliminated in the quarter-finals
#  5                                 +5
#  6                                 +5
#  7                                 +2
#  8                                 −2
#  9      Eliminated in the round of 16
#  10                                +7
#  11                                +5
#  12                                +2
#  13                                 0
#  14                                −2
#  15                                −3
#  16                                −6
#  17                                −2
#  18     Eliminated in the group stage
#  19                                −1
#  20                                −1
#  21                                −1
#  22                                −1
#  23                                −3
#  24                                −3
#  25                                −5
#  26                                −5  ,
#           Territory       Rights holder(s)        Ref.
#  0          Algeria                   EPTV       [101]
#  1          Andorra                LaLiga+       [102]
#  2           Angola                    TPA       [103]
#  3        Australia            beIN Sports       [104]
#  4          Austria           Sportdigital       [105]
#  ..             ...                    ...         ...
#  65         Ukraine                 MEGOGO       [138]
#  66  United Kingdom  BBC Three, Sky Sports   [99][139]
#  67   United States            beIN Sports       [112]
#  68          Zambia       ZNBC, Diamond TV  [111][140]
#  69        Zimbabwe                    ZBC       [111]
#
#  [70 rows x 3 columns],
#    vte2023 Africa Cup of Nations  \
#  0                        Stages
#  1           General information
#
#                       vte2023 Africa Cup of Nations.1
#  0  Group stage Group A Group B Group C Group D Gr...
#  1  Qualification Squads Gambia team flight incide...  ,
#                vte2023 Africa Cup of Nations stadiums  \
#  0  Alassane Ouattara Stadium (Abidjan) Felix Houp...
#
#              vte2023 Africa Cup of Nations stadiums.1
#  0  Alassane Ouattara Stadium (Abidjan) Felix Houp...  ,
#                              vteAfrica Cup of Nations  \
#  0                                           Editions
#  1                                      Qualification
#  2                                             Finals
#  3                                               Bids
#  4                                             Squads
#  5                                         Statistics
#  6                                      Miscellaneous
#  7  Notes: The 2021 and 2023 tournaments were actu...
#
#                            vteAfrica Cup of Nations.1
#  0  Sudan 1957 United Arab Republic 1959 Ethiopia ...
#  1  1957 1959 1962 1963 1965 1968 1970 1972 1974 1...
#  2  1957 1959 1962 1963 1965 1968 1970 1972 1974 1...
#  3                                               2027
#  4  1957 1959 1962 1963 1965 1968 1970 1972 1974 1...
#  5  Finals Appearances Awards Records and statisti...
#  6                                Balls Mascots Music
#  7  Notes: The 2021 and 2023 tournaments were actu...  ,
#    vte2023–24 in African football (CAF)  \
#  0                  « 2022–23 2024–25 »
#  1                     Domestic leagues
#  2                        Domestic cups
#  3                           Super cups
#  4           Regional club competitions
#  5                CAF club competitions
#  6           International competitions
#
#                vte2023–24 in African football (CAF).1
#  0                                « 2022–23 2024–25 »
#  1  Algeria Angola Benin Botswana Burkina Faso Bur...
#  2  Algeria Angola Botswana Burundi Cameroon ('23)...
#  3                       Algeria Angola Egypt Tunisia
#  4                            Arab Club Champions Cup
#  5  CAF Champions League qualifying rounds group s...
#  6                         2023 Africa Cup of Nations  ]

# %% [markdown]
# As can be seen, the Wikipedia page does not simply contain the AFCON groups/tables only.  There is other information that might not be relevant to me for this particular project.  I will show a few elements of the Wikipedia page in the cells below.

# %%
all_group_tables[12]
# Out:
#        Nigeria     1–1 Equatorial Guinea
# 0  Osimhen 38'  Report      Salvador 36'

# %% [markdown]
# By observing the orignal 'all_group_tables' data that I imported from Wikipedia, I notice that the specific group table relating to the fixture "Ivory Coast	v	Nigeria" thatI found in my random search **all_group_tables[12]** is a few elements before that fixture list.  I *guesstimate* that the group will be found in the 9th element of the page, as seen below.

# %% [markdown]
# The table above is the table for group A. Another *guesstimate* shows me that Group B is foundin the 16th element of our data. I will now test this for all the 6 groups.

# %% [markdown]
# ### Modifying column names

# %%
for table_ref in range(8,50,7):
    print(table_ref)
# Out:
# 8
# 15
# 22
# 29
# 36
# 43

# %% [markdown]
# To link my table reference numbers to an actual group name, I imported the **ascii_uppercase library** as **alphabet** to assist me.

# %%
alphabet
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
fix_A =all_group_tables[9:15]
fix_B = all_group_tables[16:22]
fix_C =all_group_tables[23:29]
fix_D =all_group_tables[30:36]
fix_E =all_group_tables[37:43]
fix_F =all_group_tables[44:50]

# %%
fix_A
# Out:
# [                                               Pot 1  \
#  0  Ivory Coast (50) (hosts) Morocco (13) Senegal ...
#
#                                                 Pot 2  \
#  0  Nigeria (40) Cameroon (41) Mali (49) Burkina F...
#
#                                                 Pot 3  \
#  0  South Africa (65) Cape Verde (71) Guinea (81) ...
#
#                                                 Pot 4
#  0  Guinea-Bissau (106) Mozambique (113) Namibia (...  ,
#     Pos  \
#  0    1
#  1    2
#  2    3
#  3    4
#
#    Team.mw-parser-output .hlist dl,.mw-parser-output .hlist ol,.mw-parser-output .hlist ul{margin:0;padding:0}.mw-parser-output .hlist dd,.mw-parser-output .hlist dt,.mw-parser-output .hlist li{margin:0;display:inline}.mw-parser-output .hlist.inline,.mw-parser-output .hlist.inline dl,.mw-parser-output .hlist.inline ol,.mw-parser-output .hlist.inline ul,.mw-parser-output .hlist dl dl,.mw-parser-output .hlist dl ol,.mw-parser-output .hlist dl ul,.mw-parser-output .hlist ol dl,.mw-parser-output .hlist ol ol,.mw-parser-output .hlist ol ul,.mw-parser-output .hlist ul dl,.mw-parser-output .hlist ul ol,.mw-parser-output .hlist ul ul{display:inline}.mw-parser-output .hlist .mw-empty-li{display:none}.mw-parser-output .hlist dt::after{content:": "}.mw-parser-output .hlist dd::after,.mw-parser-output .hlist li::after{content:" · ";font-weight:bold}.mw-parser-output .hlist dd:last-child::after,.mw-parser-output .hlist dt:last-child::after,.mw-parser-output .hlist li:last-child::after{content:none}.mw-parser-output .hlist dd dd:first-child::before,.mw-parser-output .hlist dd dt:first-child::before,.mw-parser-output .hlist dd li:first-child::before,.mw-parser-output .hlist dt dd:first-child::before,.mw-parser-output .hlist dt dt:first-child::before,.mw-parser-output .hlist dt li:first-child::before,.mw-parser-output .hlist li dd:first-child::before,.mw-parser-output .hlist li dt:first-child::before,.mw-parser-output .hlist li li:first-child::before{content:" (";font-weight:normal}.mw-parser-output .hlist dd dd:last-child::after,.mw-parser-output .hlist dd dt:last-child::after,.mw-parser-output .hlist dd li:last-child::after,.mw-parser-output .hlist dt dd:last-child::after,.mw-parser-output .hlist dt dt:last-child::after,.mw-parser-output .hlist dt li:last-child::after,.mw-parser-output .hlist li dd:last-child::after,.mw-parser-output .hlist li dt:last-child::after,.mw-parser-output .hlist li li:last-child::after{content:")";font-weight:normal}.mw-parser-output .hlist ol{counter-reset:listitem}.mw-parser-output .hlist ol>li{counter-increment:listitem}.mw-parser-output .hlist ol>li::before{content:" "counter(listitem)"\a0 "}.mw-parser-output .hlist dd ol>li:first-child::before,.mw-parser-output .hlist dt ol>li:first-child::before,.mw-parser-output .hlist li ol>li:first-child::before{content:" ("counter(listitem)"\a0 "}.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte  \
#  0                                  Equatorial Guinea
#  1                                            Nigeria
#  2                                    Ivory Coast (H)
#  3                                      Guinea-Bissau
#
#     Pld  W  D  L  GF  GA  GD   Pts              Qualification
#  0    3  2  1  0   9   3  +6  7[a]  Advance to knockout stage
#  1    3  2  1  0   3   1  +2  7[a]  Advance to knockout stage
#  2    3  1  0  2   2   5  −3     3  Advance to knockout stage
#  3    3  0  0  3   2   7  −5     0                        NaN  ,
#                                           Ivory Coast     2–0  Guinea-Bissau
#  0  .mw-parser-output .plainlist ol,.mw-parser-out...  Report            NaN,
#         Nigeria     1–1 Equatorial Guinea
#  0  Osimhen 38'  Report      Salvador 36',
#                  Equatorial Guinea     4–2                      Guinea-Bissau
#  0  Nsue 21', 51', 61' Miranda 46'  Report  Esteban 37' (o.g.) Zé Turbo 90+3',
#     Ivory Coast     0–1                  Nigeria
#  0          NaN  Report  Troost-Ekong 55' (pen.)]

# %%
fix_A[0]
# Out:
#                                                Pot 1  \
# 0  Ivory Coast (50) (hosts) Morocco (13) Senegal ...
#
#                                                Pot 2  \
# 0  Nigeria (40) Cameroon (41) Mali (49) Burkina F...
#
#                                                Pot 3  \
# 0  South Africa (65) Cape Verde (71) Guinea (81) ...
#
#                                                Pot 4
# 0  Guinea-Bissau (106) Mozambique (113) Namibia (...

# %%
wiki = 'https://en.wikipedia.org/wiki/2023_Africa_Cup_of_Nations'
response = requests.get(wiki)
wiki_content = response.text
soup = BeautifulSoup(wiki_content, 'lxml') # lxml  parser is responsible for reading the HTML or XML content

# %%
# I used BeautifulSoup to find all HTML elements with the class 'footballbox' in the parsed HTML content and stored them in the "afcon74_games" variable. 
afcon23_games = soup.find_all('table', class_='fevent')

# %%
home = []
score = []
away = []

# Extract information from each game element in afcon74_games
    # - 'home' stores the home team name
    # - 'score' stores the match score
    # - 'away' stores the away team name
for game in afcon23_games:
    #  get_text() is used to extract the home team name, score, and away team name from the HTML element
    home.append(game.find('th', class_ = 'fhome').get_text()) 
    score.append(game.find('th', class_ = 'fscore').get_text())
    away.append(game.find('th', class_ = 'faway').get_text())

# %%
dict_afcon23 = {'home':home, 'score':score, 'away': away}

# %%
afcon23_df= pd.DataFrame(dict_afcon23)

# %%
afcon23_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   home    52 non-null     object
#  1   score   52 non-null     object
#  2   away    52 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
import pandas as pd

# Assuming afcon23_df contains your existing fixture data
# afcon23_df = ...

# DataFrame with knockout round fixtures
afcon23_df_KO = pd.DataFrame([['1D', "", '3BEF'], ['2A', "", '2C'], ['1A', "", '3CDE'], ['2B', "", '2F'], ['1B', "", '3ACD'], 
                              ['1C', "", '3ABF'], ['1E', "", '2D'], ['1F', "", '2E']],
                             columns=['home', 'score', 'away'])

# Concatenate the two DataFrames
afcon23_df = pd.concat([afcon23_df, afcon23_df_KO], ignore_index=True)

# Now afcon23_df contains both the existing fixtures and the knockout round fixtures

# %%
afcon23_df
# Out:
#                   home         score                away
# 0         Ivory Coast            2–0       Guinea-Bissau
# 1             Nigeria            1–1   Equatorial Guinea
# 2   Equatorial Guinea            4–2       Guinea-Bissau
# 3         Ivory Coast            0–1             Nigeria
# 4   Equatorial Guinea            4–0         Ivory Coast
# 5       Guinea-Bissau            0–1             Nigeria
# 6               Egypt            2–2          Mozambique
# 7               Ghana            1–2          Cape Verde
# 8               Egypt            2–2               Ghana
# 9          Cape Verde            3–0          Mozambique
# 10         Mozambique            2–2               Ghana
# 11         Cape Verde            2–2               Egypt
# 12            Senegal            3–0              Gambia
# 13           Cameroon            1–1              Guinea
# 14            Senegal            3–1            Cameroon
# 15             Guinea            1–0              Gambia
# 16             Guinea            0–2             Senegal
# 17             Gambia            2–3            Cameroon
# 18            Algeria            1–1              Angola
# 19       Burkina Faso            1–0          Mauritania
# 20            Algeria            2–2        Burkina Faso
# 21         Mauritania            2–3              Angola
# 22             Angola            2–0        Burkina Faso
# 23         Mauritania            1–0             Algeria
# 24            Tunisia            0–1             Namibia
# 25               Mali            2–0        South Africa
# 26            Tunisia            1–1                Mali
# 27       South Africa            4–0             Namibia
# 28       South Africa            0–0             Tunisia
# 29            Namibia            0–0                Mali
# 30            Morocco            3–0            Tanzania
# 31           DR Congo            1–1              Zambia
# 32            Morocco            1–1            DR Congo
# 33             Zambia            1–1            Tanzania
# 34           Tanzania            0–0            DR Congo
# 35             Zambia            0–1             Morocco
# 36             Angola            3–0             Namibia
# 37            Nigeria            2–0            Cameroon
# 38  Equatorial Guinea            0–1              Guinea
# 39              Egypt   1–1 (a.e.t.)            DR Congo
# 40         Cape Verde            1–0          Mauritania
# 41            Senegal   1–1 (a.e.t.)         Ivory Coast
# 42               Mali            2–1        Burkina Faso
# 43            Morocco            0–2        South Africa
# 44            Nigeria            1–0              Angola
# 45           DR Congo            3–1              Guinea
# 46               Mali   1–2 (a.e.t.)         Ivory Coast
# 47         Cape Verde   0–0 (a.e.t.)        South Africa
# 48            Nigeria   1–1 (a.e.t.)        South Africa
# 49        Ivory Coast            1–0            DR Congo
# 50       South Africa            0–0            DR Congo
# 51            Nigeria            1–2         Ivory Coast
# 52                  1D                              3BEF
# 53                  2A                                2C
# 54                  1A                              3CDE
# 55                  2B                                2F
# 56                  1B                              3ACD
# 57                  1C                              3ABF
# 58                  1E                                2D
# 59                  1F                                2E

# %%
afcon23_df = afcon23_df.drop([37, 38])

# %%
afcon23_df
# Out:
#                   home         score                away
# 0         Ivory Coast            2–0       Guinea-Bissau
# 1             Nigeria            1–1   Equatorial Guinea
# 2   Equatorial Guinea            4–2       Guinea-Bissau
# 3         Ivory Coast            0–1             Nigeria
# 4   Equatorial Guinea            4–0         Ivory Coast
# 5       Guinea-Bissau            0–1             Nigeria
# 6               Egypt            2–2          Mozambique
# 7               Ghana            1–2          Cape Verde
# 8               Egypt            2–2               Ghana
# 9          Cape Verde            3–0          Mozambique
# 10         Mozambique            2–2               Ghana
# 11         Cape Verde            2–2               Egypt
# 12            Senegal            3–0              Gambia
# 13           Cameroon            1–1              Guinea
# 14            Senegal            3–1            Cameroon
# 15             Guinea            1–0              Gambia
# 16             Guinea            0–2             Senegal
# 17             Gambia            2–3            Cameroon
# 18            Algeria            1–1              Angola
# 19       Burkina Faso            1–0          Mauritania
# 20            Algeria            2–2        Burkina Faso
# 21         Mauritania            2–3              Angola
# 22             Angola            2–0        Burkina Faso
# 23         Mauritania            1–0             Algeria
# 24            Tunisia            0–1             Namibia
# 25               Mali            2–0        South Africa
# 26            Tunisia            1–1                Mali
# 27       South Africa            4–0             Namibia
# 28       South Africa            0–0             Tunisia
# 29            Namibia            0–0                Mali
# 30            Morocco            3–0            Tanzania
# 31           DR Congo            1–1              Zambia
# 32            Morocco            1–1            DR Congo
# 33             Zambia            1–1            Tanzania
# 34           Tanzania            0–0            DR Congo
# 35             Zambia            0–1             Morocco
# 36             Angola            3–0             Namibia
# 39              Egypt   1–1 (a.e.t.)            DR Congo
# 40         Cape Verde            1–0          Mauritania
# 41            Senegal   1–1 (a.e.t.)         Ivory Coast
# 42               Mali            2–1        Burkina Faso
# 43            Morocco            0–2        South Africa
# 44            Nigeria            1–0              Angola
# 45           DR Congo            3–1              Guinea
# 46               Mali   1–2 (a.e.t.)         Ivory Coast
# 47         Cape Verde   0–0 (a.e.t.)        South Africa
# 48            Nigeria   1–1 (a.e.t.)        South Africa
# 49        Ivory Coast            1–0            DR Congo
# 50       South Africa            0–0            DR Congo
# 51            Nigeria            1–2         Ivory Coast
# 52                  1D                              3BEF
# 53                  2A                                2C
# 54                  1A                              3CDE
# 55                  2B                                2F
# 56                  1B                              3ACD
# 57                  1C                              3ABF
# 58                  1E                                2D
# 59                  1F                                2E

# %%
afcon23_df['Stage'] = "KO"
afcon23_df
# Out:
#                   home         score                away Stage
# 0         Ivory Coast            2–0       Guinea-Bissau    KO
# 1             Nigeria            1–1   Equatorial Guinea    KO
# 2   Equatorial Guinea            4–2       Guinea-Bissau    KO
# 3         Ivory Coast            0–1             Nigeria    KO
# 4   Equatorial Guinea            4–0         Ivory Coast    KO
# 5       Guinea-Bissau            0–1             Nigeria    KO
# 6               Egypt            2–2          Mozambique    KO
# 7               Ghana            1–2          Cape Verde    KO
# 8               Egypt            2–2               Ghana    KO
# 9          Cape Verde            3–0          Mozambique    KO
# 10         Mozambique            2–2               Ghana    KO
# 11         Cape Verde            2–2               Egypt    KO
# 12            Senegal            3–0              Gambia    KO
# 13           Cameroon            1–1              Guinea    KO
# 14            Senegal            3–1            Cameroon    KO
# 15             Guinea            1–0              Gambia    KO
# 16             Guinea            0–2             Senegal    KO
# 17             Gambia            2–3            Cameroon    KO
# 18            Algeria            1–1              Angola    KO
# 19       Burkina Faso            1–0          Mauritania    KO
# 20            Algeria            2–2        Burkina Faso    KO
# 21         Mauritania            2–3              Angola    KO
# 22             Angola            2–0        Burkina Faso    KO
# 23         Mauritania            1–0             Algeria    KO
# 24            Tunisia            0–1             Namibia    KO
# 25               Mali            2–0        South Africa    KO
# 26            Tunisia            1–1                Mali    KO
# 27       South Africa            4–0             Namibia    KO
# 28       South Africa            0–0             Tunisia    KO
# 29            Namibia            0–0                Mali    KO
# 30            Morocco            3–0            Tanzania    KO
# 31           DR Congo            1–1              Zambia    KO
# 32            Morocco            1–1            DR Congo    KO
# 33             Zambia            1–1            Tanzania    KO
# 34           Tanzania            0–0            DR Congo    KO
# 35             Zambia            0–1             Morocco    KO
# 36             Angola            3–0             Namibia    KO
# 39              Egypt   1–1 (a.e.t.)            DR Congo    KO
# 40         Cape Verde            1–0          Mauritania    KO
# 41            Senegal   1–1 (a.e.t.)         Ivory Coast    KO
# 42               Mali            2–1        Burkina Faso    KO
# 43            Morocco            0–2        South Africa    KO
# 44            Nigeria            1–0              Angola    KO
# 45           DR Congo            3–1              Guinea    KO
# 46               Mali   1–2 (a.e.t.)         Ivory Coast    KO
# 47         Cape Verde   0–0 (a.e.t.)        South Africa    KO
# 48            Nigeria   1–1 (a.e.t.)        South Africa    KO
# 49        Ivory Coast            1–0            DR Congo    KO
# 50       South Africa            0–0            DR Congo    KO
# 51            Nigeria            1–2         Ivory Coast    KO
# 52                  1D                              3BEF    KO
# 53                  2A                                2C    KO
# 54                  1A                              3CDE    KO
# 55                  2B                                2F    KO
# 56                  1B                              3ACD    KO
# 57                  1C                              3ABF    KO
# 58                  1E                                2D    KO
# 59                  1F                                2E    KO

# %%
afcon23_df.loc[:37, 'stage'] = 'Group'
afcon23_df
# Out:
#                   home         score                away Stage  stage
# 0         Ivory Coast            2–0       Guinea-Bissau    KO  Group
# 1             Nigeria            1–1   Equatorial Guinea    KO  Group
# 2   Equatorial Guinea            4–2       Guinea-Bissau    KO  Group
# 3         Ivory Coast            0–1             Nigeria    KO  Group
# 4   Equatorial Guinea            4–0         Ivory Coast    KO  Group
# 5       Guinea-Bissau            0–1             Nigeria    KO  Group
# 6               Egypt            2–2          Mozambique    KO  Group
# 7               Ghana            1–2          Cape Verde    KO  Group
# 8               Egypt            2–2               Ghana    KO  Group
# 9          Cape Verde            3–0          Mozambique    KO  Group
# 10         Mozambique            2–2               Ghana    KO  Group
# 11         Cape Verde            2–2               Egypt    KO  Group
# 12            Senegal            3–0              Gambia    KO  Group
# 13           Cameroon            1–1              Guinea    KO  Group
# 14            Senegal            3–1            Cameroon    KO  Group
# 15             Guinea            1–0              Gambia    KO  Group
# 16             Guinea            0–2             Senegal    KO  Group
# 17             Gambia            2–3            Cameroon    KO  Group
# 18            Algeria            1–1              Angola    KO  Group
# 19       Burkina Faso            1–0          Mauritania    KO  Group
# 20            Algeria            2–2        Burkina Faso    KO  Group
# 21         Mauritania            2–3              Angola    KO  Group
# 22             Angola            2–0        Burkina Faso    KO  Group
# 23         Mauritania            1–0             Algeria    KO  Group
# 24            Tunisia            0–1             Namibia    KO  Group
# 25               Mali            2–0        South Africa    KO  Group
# 26            Tunisia            1–1                Mali    KO  Group
# 27       South Africa            4–0             Namibia    KO  Group
# 28       South Africa            0–0             Tunisia    KO  Group
# 29            Namibia            0–0                Mali    KO  Group
# 30            Morocco            3–0            Tanzania    KO  Group
# 31           DR Congo            1–1              Zambia    KO  Group
# 32            Morocco            1–1            DR Congo    KO  Group
# 33             Zambia            1–1            Tanzania    KO  Group
# 34           Tanzania            0–0            DR Congo    KO  Group
# 35             Zambia            0–1             Morocco    KO  Group
# 36             Angola            3–0             Namibia    KO  Group
# 39              Egypt   1–1 (a.e.t.)            DR Congo    KO    NaN
# 40         Cape Verde            1–0          Mauritania    KO    NaN
# 41            Senegal   1–1 (a.e.t.)         Ivory Coast    KO    NaN
# 42               Mali            2–1        Burkina Faso    KO    NaN
# 43            Morocco            0–2        South Africa    KO    NaN
# 44            Nigeria            1–0              Angola    KO    NaN
# 45           DR Congo            3–1              Guinea    KO    NaN
# 46               Mali   1–2 (a.e.t.)         Ivory Coast    KO    NaN
# 47         Cape Verde   0–0 (a.e.t.)        South Africa    KO    NaN
# 48            Nigeria   1–1 (a.e.t.)        South Africa    KO    NaN
# 49        Ivory Coast            1–0            DR Congo    KO    NaN
# 50       South Africa            0–0            DR Congo    KO    NaN
# 51            Nigeria            1–2         Ivory Coast    KO    NaN
# 52                  1D                              3BEF    KO    NaN
# 53                  2A                                2C    KO    NaN
# 54                  1A                              3CDE    KO    NaN
# 55                  2B                                2F    KO    NaN
# 56                  1B                              3ACD    KO    NaN
# 57                  1C                              3ABF    KO    NaN
# 58                  1E                                2D    KO    NaN
# 59                  1F                                2E    KO    NaN

# %%
afcon23_df.loc[39:46, 'stage'] = 'L16'
afcon23_df
# Out:
#                   home         score                away Stage  stage
# 0         Ivory Coast            2–0       Guinea-Bissau    KO  Group
# 1             Nigeria            1–1   Equatorial Guinea    KO  Group
# 2   Equatorial Guinea            4–2       Guinea-Bissau    KO  Group
# 3         Ivory Coast            0–1             Nigeria    KO  Group
# 4   Equatorial Guinea            4–0         Ivory Coast    KO  Group
# 5       Guinea-Bissau            0–1             Nigeria    KO  Group
# 6               Egypt            2–2          Mozambique    KO  Group
# 7               Ghana            1–2          Cape Verde    KO  Group
# 8               Egypt            2–2               Ghana    KO  Group
# 9          Cape Verde            3–0          Mozambique    KO  Group
# 10         Mozambique            2–2               Ghana    KO  Group
# 11         Cape Verde            2–2               Egypt    KO  Group
# 12            Senegal            3–0              Gambia    KO  Group
# 13           Cameroon            1–1              Guinea    KO  Group
# 14            Senegal            3–1            Cameroon    KO  Group
# 15             Guinea            1–0              Gambia    KO  Group
# 16             Guinea            0–2             Senegal    KO  Group
# 17             Gambia            2–3            Cameroon    KO  Group
# 18            Algeria            1–1              Angola    KO  Group
# 19       Burkina Faso            1–0          Mauritania    KO  Group
# 20            Algeria            2–2        Burkina Faso    KO  Group
# 21         Mauritania            2–3              Angola    KO  Group
# 22             Angola            2–0        Burkina Faso    KO  Group
# 23         Mauritania            1–0             Algeria    KO  Group
# 24            Tunisia            0–1             Namibia    KO  Group
# 25               Mali            2–0        South Africa    KO  Group
# 26            Tunisia            1–1                Mali    KO  Group
# 27       South Africa            4–0             Namibia    KO  Group
# 28       South Africa            0–0             Tunisia    KO  Group
# 29            Namibia            0–0                Mali    KO  Group
# 30            Morocco            3–0            Tanzania    KO  Group
# 31           DR Congo            1–1              Zambia    KO  Group
# 32            Morocco            1–1            DR Congo    KO  Group
# 33             Zambia            1–1            Tanzania    KO  Group
# 34           Tanzania            0–0            DR Congo    KO  Group
# 35             Zambia            0–1             Morocco    KO  Group
# 36             Angola            3–0             Namibia    KO  Group
# 39              Egypt   1–1 (a.e.t.)            DR Congo    KO    L16
# 40         Cape Verde            1–0          Mauritania    KO    L16
# 41            Senegal   1–1 (a.e.t.)         Ivory Coast    KO    L16
# 42               Mali            2–1        Burkina Faso    KO    L16
# 43            Morocco            0–2        South Africa    KO    L16
# 44            Nigeria            1–0              Angola    KO    L16
# 45           DR Congo            3–1              Guinea    KO    L16
# 46               Mali   1–2 (a.e.t.)         Ivory Coast    KO    L16
# 47         Cape Verde   0–0 (a.e.t.)        South Africa    KO    NaN
# 48            Nigeria   1–1 (a.e.t.)        South Africa    KO    NaN
# 49        Ivory Coast            1–0            DR Congo    KO    NaN
# 50       South Africa            0–0            DR Congo    KO    NaN
# 51            Nigeria            1–2         Ivory Coast    KO    NaN
# 52                  1D                              3BEF    KO    NaN
# 53                  2A                                2C    KO    NaN
# 54                  1A                              3CDE    KO    NaN
# 55                  2B                                2F    KO    NaN
# 56                  1B                              3ACD    KO    NaN
# 57                  1C                              3ABF    KO    NaN
# 58                  1E                                2D    KO    NaN
# 59                  1F                                2E    KO    NaN

# %%
afcon23_df['ko_label'] = ''
afcon23_df
# Out:
#                   home         score                away Stage  stage ko_label
# 0         Ivory Coast            2–0       Guinea-Bissau    KO  Group
# 1             Nigeria            1–1   Equatorial Guinea    KO  Group
# 2   Equatorial Guinea            4–2       Guinea-Bissau    KO  Group
# 3         Ivory Coast            0–1             Nigeria    KO  Group
# 4   Equatorial Guinea            4–0         Ivory Coast    KO  Group
# 5       Guinea-Bissau            0–1             Nigeria    KO  Group
# 6               Egypt            2–2          Mozambique    KO  Group
# 7               Ghana            1–2          Cape Verde    KO  Group
# 8               Egypt            2–2               Ghana    KO  Group
# 9          Cape Verde            3–0          Mozambique    KO  Group
# 10         Mozambique            2–2               Ghana    KO  Group
# 11         Cape Verde            2–2               Egypt    KO  Group
# 12            Senegal            3–0              Gambia    KO  Group
# 13           Cameroon            1–1              Guinea    KO  Group
# 14            Senegal            3–1            Cameroon    KO  Group
# 15             Guinea            1–0              Gambia    KO  Group
# 16             Guinea            0–2             Senegal    KO  Group
# 17             Gambia            2–3            Cameroon    KO  Group
# 18            Algeria            1–1              Angola    KO  Group
# 19       Burkina Faso            1–0          Mauritania    KO  Group
# 20            Algeria            2–2        Burkina Faso    KO  Group
# 21         Mauritania            2–3              Angola    KO  Group
# 22             Angola            2–0        Burkina Faso    KO  Group
# 23         Mauritania            1–0             Algeria    KO  Group
# 24            Tunisia            0–1             Namibia    KO  Group
# 25               Mali            2–0        South Africa    KO  Group
# 26            Tunisia            1–1                Mali    KO  Group
# 27       South Africa            4–0             Namibia    KO  Group
# 28       South Africa            0–0             Tunisia    KO  Group
# 29            Namibia            0–0                Mali    KO  Group
# 30            Morocco            3–0            Tanzania    KO  Group
# 31           DR Congo            1–1              Zambia    KO  Group
# 32            Morocco            1–1            DR Congo    KO  Group
# 33             Zambia            1–1            Tanzania    KO  Group
# 34           Tanzania            0–0            DR Congo    KO  Group
# 35             Zambia            0–1             Morocco    KO  Group
# 36             Angola            3–0             Namibia    KO  Group
# 39              Egypt   1–1 (a.e.t.)            DR Congo    KO    L16
# 40         Cape Verde            1–0          Mauritania    KO    L16
# 41            Senegal   1–1 (a.e.t.)         Ivory Coast    KO    L16
# 42               Mali            2–1        Burkina Faso    KO    L16
# 43            Morocco            0–2        South Africa    KO    L16
# 44            Nigeria            1–0              Angola    KO    L16
# 45           DR Congo            3–1              Guinea    KO    L16
# 46               Mali   1–2 (a.e.t.)         Ivory Coast    KO    L16
# 47         Cape Verde   0–0 (a.e.t.)        South Africa    KO    NaN
# 48            Nigeria   1–1 (a.e.t.)        South Africa    KO    NaN
# 49        Ivory Coast            1–0            DR Congo    KO    NaN
# 50       South Africa            0–0            DR Congo    KO    NaN
# 51            Nigeria            1–2         Ivory Coast    KO    NaN
# 52                  1D                              3BEF    KO    NaN
# 53                  2A                                2C    KO    NaN
# 54                  1A                              3CDE    KO    NaN
# 55                  2B                                2F    KO    NaN
# 56                  1B                              3ACD    KO    NaN
# 57                  1C                              3ABF    KO    NaN
# 58                  1E                                2D    KO    NaN
# 59                  1F                                2E    KO    NaN

# %%
afcon23_df = afcon23_df.drop(36)
afcon23_df
# Out:
#                   home         score                away Stage  stage ko_label
# 0         Ivory Coast            2–0       Guinea-Bissau    KO  Group
# 1             Nigeria            1–1   Equatorial Guinea    KO  Group
# 2   Equatorial Guinea            4–2       Guinea-Bissau    KO  Group
# 3         Ivory Coast            0–1             Nigeria    KO  Group
# 4   Equatorial Guinea            4–0         Ivory Coast    KO  Group
# 5       Guinea-Bissau            0–1             Nigeria    KO  Group
# 6               Egypt            2–2          Mozambique    KO  Group
# 7               Ghana            1–2          Cape Verde    KO  Group
# 8               Egypt            2–2               Ghana    KO  Group
# 9          Cape Verde            3–0          Mozambique    KO  Group
# 10         Mozambique            2–2               Ghana    KO  Group
# 11         Cape Verde            2–2               Egypt    KO  Group
# 12            Senegal            3–0              Gambia    KO  Group
# 13           Cameroon            1–1              Guinea    KO  Group
# 14            Senegal            3–1            Cameroon    KO  Group
# 15             Guinea            1–0              Gambia    KO  Group
# 16             Guinea            0–2             Senegal    KO  Group
# 17             Gambia            2–3            Cameroon    KO  Group
# 18            Algeria            1–1              Angola    KO  Group
# 19       Burkina Faso            1–0          Mauritania    KO  Group
# 20            Algeria            2–2        Burkina Faso    KO  Group
# 21         Mauritania            2–3              Angola    KO  Group
# 22             Angola            2–0        Burkina Faso    KO  Group
# 23         Mauritania            1–0             Algeria    KO  Group
# 24            Tunisia            0–1             Namibia    KO  Group
# 25               Mali            2–0        South Africa    KO  Group
# 26            Tunisia            1–1                Mali    KO  Group
# 27       South Africa            4–0             Namibia    KO  Group
# 28       South Africa            0–0             Tunisia    KO  Group
# 29            Namibia            0–0                Mali    KO  Group
# 30            Morocco            3–0            Tanzania    KO  Group
# 31           DR Congo            1–1              Zambia    KO  Group
# 32            Morocco            1–1            DR Congo    KO  Group
# 33             Zambia            1–1            Tanzania    KO  Group
# 34           Tanzania            0–0            DR Congo    KO  Group
# 35             Zambia            0–1             Morocco    KO  Group
# 39              Egypt   1–1 (a.e.t.)            DR Congo    KO    L16
# 40         Cape Verde            1–0          Mauritania    KO    L16
# 41            Senegal   1–1 (a.e.t.)         Ivory Coast    KO    L16
# 42               Mali            2–1        Burkina Faso    KO    L16
# 43            Morocco            0–2        South Africa    KO    L16
# 44            Nigeria            1–0              Angola    KO    L16
# 45           DR Congo            3–1              Guinea    KO    L16
# 46               Mali   1–2 (a.e.t.)         Ivory Coast    KO    L16
# 47         Cape Verde   0–0 (a.e.t.)        South Africa    KO    NaN
# 48            Nigeria   1–1 (a.e.t.)        South Africa    KO    NaN
# 49        Ivory Coast            1–0            DR Congo    KO    NaN
# 50       South Africa            0–0            DR Congo    KO    NaN
# 51            Nigeria            1–2         Ivory Coast    KO    NaN
# 52                  1D                              3BEF    KO    NaN
# 53                  2A                                2C    KO    NaN
# 54                  1A                              3CDE    KO    NaN
# 55                  2B                                2F    KO    NaN
# 56                  1B                              3ACD    KO    NaN
# 57                  1C                              3ABF    KO    NaN
# 58                  1E                                2D    KO    NaN
# 59                  1F                                2E    KO    NaN

# %%
afcon23_df.to_csv('afcon23_fixtures_group_L16.csv', index=False)
