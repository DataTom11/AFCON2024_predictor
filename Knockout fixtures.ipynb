# %% [markdown]
# # AFCON 2023 project

# %%
import pandas as pd
from string import ascii_uppercase as alphabet
import pickle
from bs4 import BeautifulSoup # to parse HTML or XML documents and extract data 
import requests # to aend requests to the website (wikipedia) that I am going to scrape

# %% [markdown]
# # Scraping data from the internet relating to AFCON 2023/24

# %%
all_group_tables = pd.read_html('https://en.wikipedia.org/wiki/2023_Africa_Cup_of_Nations')

# %%
all_group_tables
# Out:
# [  Coupe d'Afrique des Nations 2023 Coupe d'Afrique des Nations 2023.1
#  0                 Official logo[1]                   Official logo[1]
#  1               Tournament details                 Tournament details
#  2                     Host country                        Ivory Coast
#  3                            Dates      13 January – 11 February 2024
#  4                            Teams                                 24
#  5                         Venue(s)               6 (in 5 host cities)
#  6                    ← 2021 2025 →                      ← 2021 2025 →,
#             Title sponsor            Official sponsors Regional sponsors
#  0  Total 1XBET Visa Puma  Apsonic[15] Tecno[16] Razzl    Celeste Porteo
#  1            Total 1XBET                    Visa Puma               NaN
#  2  Apsonic[15] Tecno[16]                        Razzl               NaN,
#               0          1
#  0  Total 1XBET  Visa Puma,
#                         0      1
#  0  Apsonic[15] Tecno[16]  Razzl,
#                   Team      Method ofqualification Date ofqualification  \
#  0         Ivory Coast  Hosts / Group H runners-up      30 January 2019
#  1             Morocco             Group K winners        24 March 2023
#  2             Algeria             Group F winners        27 March 2023
#  3        South Africa          Group K runners-up        28 March 2023
#  4             Senegal             Group L winners        28 March 2023
#  5        Burkina Faso             Group B winners        28 March 2023
#  6             Tunisia             Group J winners        28 March 2023
#  7               Egypt             Group D winners         14 June 2023
#  8              Zambia             Group H winners         17 June 2023
#  9   Equatorial Guinea          Group J runners-up         17 June 2023
#  10            Nigeria             Group A winners         18 June 2023
#  11      Guinea-Bissau          Group A runners-up         18 June 2023
#  12         Cape Verde          Group B runners-up         18 June 2023
#  13               Mali             Group G winners         18 June 2023
#  14             Guinea          Group D runners-up         20 June 2023
#  15              Ghana             Group E winners     7 September 2023
#  16             Angola          Group E runners-up     7 September 2023
#  17           Tanzania          Group F runners-up     7 September 2023
#  18         Mozambique          Group L runners-up     9 September 2023
#  19           DR Congo             Group I winners     9 September 2023
#  20         Mauritania          Group I runners-up     9 September 2023
#  21             Gambia          Group G runners-up    10 September 2023
#  22           Cameroon             Group C winners    12 September 2023
#  23            Namibia          Group C runners-up    12 September 2023
#
#     Finalsappearance  Lastappearance  \
#  0              25th            2021
#  1              19th            2021
#  2              20th            2021
#  3              11th            2019
#  4              17th            2021
#  5              13th            2021
#  6              21st            2021
#  7              26th            2021
#  8              18th            2015
#  9               4th            2021
#  10             20th            2021
#  11              4th            2021
#  12              4th            2021
#  13             13th            2021
#  14             14th            2021
#  15             24th            2021
#  16              9th            2019
#  17              3rd            2019
#  18              5th            2010
#  19             20th            2019
#  20              3rd            2021
#  21              2nd            2021
#  22             21st            2021
#  23              4th            2019
#
#                               Previous bestperformance
#  0                              Champions (1992, 2015)
#  1                                    Champions (1976)
#  2                              Champions (1990, 2019)
#  3                                    Champions (1996)
#  4                                    Champions (2021)
#  5                                   Runners-up (2013)
#  6                                    Champions (2004)
#  7   Champions (1957, 1959, 1986, 1998, 2006, 2008,...
#  8                                    Champions (2012)
#  9                                 Fourth place (2015)
#  10                       Champions (1980, 1994, 2013)
#  11                     Group stage (2017, 2019, 2021)
#  12                              Quarter-finals (2013)
#  13                                  Runners-up (1972)
#  14                                  Runners-up (1976)
#  15                 Champions (1963, 1965, 1978, 1982)
#  16                        Quarter-finals (2008, 2010)
#  17                           Group stage (1980, 2019)
#  18               Group stage (1986, 1996, 1998, 2010)
#  19                             Champions (1968, 1974)
#  20                           Group stage (2019, 2021)
#  21                              Quarter-finals (2021)
#  22           Champions (1984, 1988, 2000, 2002, 2017)
#  23                     Group stage (1998, 2008, 2019)  ,
#     Number of stadiums  Capacity(Minimum)
#  0                   2              40000
#  1                   2              20000
#  2                   2              15000,
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)  \
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#    .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}AbidjanBouakéKorhogoSan PédroYamoussoukro2023 Africa Cup of Nations (Ivory Coast)
#  0                          Alassane Ouattara Stadium
#  1                                   Capacity: 60,000
#  2                                                NaN
#  3                                            Korhogo
#  4                       Amadou Gon Coulibaly Stadium
#  5                                   Capacity: 20,000
#  6                                                NaN
#
#                            Abidjan                               \
#                 Unnamed: 1_level_1           Unnamed: 2_level_1
#                 Unnamed: 1_level_2           Unnamed: 2_level_2
#                 Unnamed: 1_level_3           Unnamed: 2_level_3
#                 Unnamed: 1_level_4           Unnamed: 2_level_4
#                 Unnamed: 1_level_5           Unnamed: 2_level_5
#                 Unnamed: 1_level_6           Unnamed: 2_level_6
#                 Unnamed: 1_level_7           Unnamed: 2_level_7
#  0  Felix Houphouet Boigny Stadium             Stade de la Paix
#  1            Capacity: 33,000[20]             Capacity: 40,000
#  2                             NaN                          NaN
#  3                       San Pédro                 Yamoussoukro
#  4           Laurent Pokou Stadium  Charles Konan Banny Stadium
#  5                Capacity: 20,000             Capacity: 20,000
#  6                             NaN                          NaN
#
#                Bouaké
#    Unnamed: 3_level_1
#    Unnamed: 3_level_2
#    Unnamed: 3_level_3
#    Unnamed: 3_level_4
#    Unnamed: 3_level_5
#    Unnamed: 3_level_6
#    Unnamed: 3_level_7
#  0                NaN
#  1                NaN
#  2                NaN
#  3                NaN
#  4                NaN
#  5                NaN
#  6                NaN  ,
#                                                 Pot 1  \
#  0  Ivory Coast (50) (hosts)  Morocco (13) Senegal...
#
#                                                 Pot 2  \
#  0  Nigeria (40) Cameroon (41) Mali (49) Burkina F...
#
#                                                 Pot 3  \
#  0  South Africa (65) Cape Verde (71) Guinea (81) ...
#
#                                                 Pot 4
#  0  Guinea-Bissau (106) Mozambique (113) Namibia (...  ,
#     Pos  \
#  0    1
#  1    2
#  2    3
#  3    4
#
#    Team.mw-parser-output .hlist dl,.mw-parser-output .hlist ol,.mw-parser-output .hlist ul{margin:0;padding:0}.mw-parser-output .hlist dd,.mw-parser-output .hlist dt,.mw-parser-output .hlist li{margin:0;display:inline}.mw-parser-output .hlist.inline,.mw-parser-output .hlist.inline dl,.mw-parser-output .hlist.inline ol,.mw-parser-output .hlist.inline ul,.mw-parser-output .hlist dl dl,.mw-parser-output .hlist dl ol,.mw-parser-output .hlist dl ul,.mw-parser-output .hlist ol dl,.mw-parser-output .hlist ol ol,.mw-parser-output .hlist ol ul,.mw-parser-output .hlist ul dl,.mw-parser-output .hlist ul ol,.mw-parser-output .hlist ul ul{display:inline}.mw-parser-output .hlist .mw-empty-li{display:none}.mw-parser-output .hlist dt::after{content:": "}.mw-parser-output .hlist dd::after,.mw-parser-output .hlist li::after{content:" · ";font-weight:bold}.mw-parser-output .hlist dd:last-child::after,.mw-parser-output .hlist dt:last-child::after,.mw-parser-output .hlist li:last-child::after{content:none}.mw-parser-output .hlist dd dd:first-child::before,.mw-parser-output .hlist dd dt:first-child::before,.mw-parser-output .hlist dd li:first-child::before,.mw-parser-output .hlist dt dd:first-child::before,.mw-parser-output .hlist dt dt:first-child::before,.mw-parser-output .hlist dt li:first-child::before,.mw-parser-output .hlist li dd:first-child::before,.mw-parser-output .hlist li dt:first-child::before,.mw-parser-output .hlist li li:first-child::before{content:" (";font-weight:normal}.mw-parser-output .hlist dd dd:last-child::after,.mw-parser-output .hlist dd dt:last-child::after,.mw-parser-output .hlist dd li:last-child::after,.mw-parser-output .hlist dt dd:last-child::after,.mw-parser-output .hlist dt dt:last-child::after,.mw-parser-output .hlist dt li:last-child::after,.mw-parser-output .hlist li dd:last-child::after,.mw-parser-output .hlist li dt:last-child::after,.mw-parser-output .hlist li li:last-child::after{content:")";font-weight:normal}.mw-parser-output .hlist ol{counter-reset:listitem}.mw-parser-output .hlist ol>li{counter-increment:listitem}.mw-parser-output .hlist ol>li::before{content:" "counter(listitem)"\a0 "}.mw-parser-output .hlist dd ol>li:first-child::before,.mw-parser-output .hlist dt ol>li:first-child::before,.mw-parser-output .hlist li ol>li:first-child::before{content:" ("counter(listitem)"\a0 "}.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte  \
#  0                                    Ivory Coast (H)
#  1                                            Nigeria
#  2                                  Equatorial Guinea
#  3                                      Guinea-Bissau
#
#     Pld  W  D  L  GF  GA  GD  Pts                             Qualification
#  0    0  0  0  0   0   0   0    0                 Advance to knockout stage
#  1    0  0  0  0   0   0   0    0                 Advance to knockout stage
#  2    0  0  0  0   0   0   0    0  Possible knockout stage based on ranking
#  3    0  0  0  0   0   0   0    0                                       NaN  ,
#     Ivory Coast   v  Guinea-Bissau
#  0          NaN NaN            NaN,
#     Nigeria   v  Equatorial Guinea
#  0      NaN NaN                NaN,
#     Equatorial Guinea   v  Guinea-Bissau
#  0                NaN NaN            NaN,
#     Ivory Coast   v  Nigeria
#  0          NaN NaN      NaN,
#     Equatorial Guinea   v  Ivory Coast
#  0                NaN NaN          NaN,
#     Guinea-Bissau   v  Nigeria
#  0            NaN NaN      NaN,
#     Pos     Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
#  0    1       Egypt    0  0  0  0   0   0   0    0
#  1    2       Ghana    0  0  0  0   0   0   0    0
#  2    3  Cape Verde    0  0  0  0   0   0   0    0
#  3    4  Mozambique    0  0  0  0   0   0   0    0
#
#                                Qualification
#  0                 Advance to knockout stage
#  1                 Advance to knockout stage
#  2  Possible knockout stage based on ranking
#  3                                       NaN  ,
#     Egypt   v  Mozambique
#  0    NaN NaN         NaN,
#     Ghana   v  Cape Verde
#  0    NaN NaN         NaN,
#     Egypt   v  Ghana
#  0    NaN NaN    NaN,
#     Cape Verde   v  Mozambique
#  0         NaN NaN         NaN,
#     Mozambique   v  Ghana
#  0         NaN NaN    NaN,
#     Cape Verde   v  Egypt
#  0         NaN NaN    NaN,
#     Pos   Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
#  0    1   Senegal    0  0  0  0   0   0   0    0
#  1    2  Cameroon    0  0  0  0   0   0   0    0
#  2    3    Guinea    0  0  0  0   0   0   0    0
#  3    4    Gambia    0  0  0  0   0   0   0    0
#
#                                Qualification
#  0                 Advance to knockout stage
#  1                 Advance to knockout stage
#  2  Possible knockout stage based on ranking
#  3                                       NaN  ,
#     Senegal   v  Gambia
#  0      NaN NaN     NaN,
#     Cameroon   v  Guinea
#  0       NaN NaN     NaN,
#     Senegal   v  Cameroon
#  0      NaN NaN       NaN,
#     Guinea   v  Gambia
#  0     NaN NaN     NaN,
#     Guinea   v  Senegal
#  0     NaN NaN      NaN,
#     Gambia   v  Cameroon
#  0     NaN NaN       NaN,
#     Pos       Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
#  0    1       Algeria    0  0  0  0   0   0   0    0
#  1    2  Burkina Faso    0  0  0  0   0   0   0    0
#  2    3    Mauritania    0  0  0  0   0   0   0    0
#  3    4        Angola    0  0  0  0   0   0   0    0
#
#                                Qualification
#  0                 Advance to knockout stage
#  1                 Advance to knockout stage
#  2  Possible knockout stage based on ranking
#  3                                       NaN  ,
#     Algeria   v  Angola
#  0      NaN NaN     NaN,
#     Burkina Faso   v  Mauritania
#  0           NaN NaN         NaN,
#     Algeria   v  Burkina Faso
#  0      NaN NaN           NaN,
#     Mauritania   v  Angola
#  0         NaN NaN     NaN,
#     Angola   v  Burkina Faso
#  0     NaN NaN           NaN,
#     Mauritania   v  Algeria
#  0         NaN NaN      NaN,
#     Pos       Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
#  0    1       Tunisia    0  0  0  0   0   0   0    0
#  1    2          Mali    0  0  0  0   0   0   0    0
#  2    3  South Africa    0  0  0  0   0   0   0    0
#  3    4       Namibia    0  0  0  0   0   0   0    0
#
#                                Qualification
#  0                 Advance to knockout stage
#  1                 Advance to knockout stage
#  2  Possible knockout stage based on ranking
#  3                                       NaN  ,
#     Tunisia   v  Namibia
#  0      NaN NaN      NaN,
#     Mali   v  South Africa
#  0   NaN NaN           NaN,
#     Tunisia   v  Mali
#  0      NaN NaN   NaN,
#     South Africa   v  Namibia
#  0           NaN NaN      NaN,
#     South Africa   v  Tunisia
#  0           NaN NaN      NaN,
#     Namibia   v  Mali
#  0      NaN NaN   NaN,
#     Pos   Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
#  0    1   Morocco    0  0  0  0   0   0   0    0
#  1    2  DR Congo    0  0  0  0   0   0   0    0
#  2    3    Zambia    0  0  0  0   0   0   0    0
#  3    4  Tanzania    0  0  0  0   0   0   0    0
#
#                                Qualification
#  0                 Advance to knockout stage
#  1                 Advance to knockout stage
#  2  Possible knockout stage based on ranking
#  3                                       NaN  ,
#     Morocco   v  Tanzania
#  0      NaN NaN       NaN,
#     DR Congo   v  Zambia
#  0       NaN NaN     NaN,
#     Morocco   v  DR Congo
#  0      NaN NaN       NaN,
#     Zambia   v  Tanzania
#  0     NaN NaN       NaN,
#     Tanzania   v  DR Congo
#  0       NaN NaN       NaN,
#     Zambia   v  Morocco
#  0     NaN NaN      NaN,
#     Pos Grp Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1   A      A3    0  0  0  0   0   0   0    0  Advance to knockout stage
#  1    2   B      B3    0  0  0  0   0   0   0    0  Advance to knockout stage
#  2    3   C      C3    0  0  0  0   0   0   0    0  Advance to knockout stage
#  3    4   D      D3    0  0  0  0   0   0   0    0  Advance to knockout stage
#  4    5   E      E3    0  0  0  0   0   0   0    0                        NaN
#  5    6   F      F3    0  0  0  0   0   0   0    0                        NaN,
#     Third-placed teamsqualify from groups  \
#  0                                    NaN
#  1                                    NaN
#  2                                    NaN
#  3                                    NaN
#  4                                    NaN
#  5                                    NaN
#  6                                    NaN
#  7                                    NaN
#  8                                    NaN
#  9                                    NaN
#  10                                   NaN
#  11                                   NaN
#  12                                   NaN
#  13                                   NaN
#  14                                   NaN
#  15                                     A
#  16                                     A
#  17                                     A
#  18                                     A
#  19                                     A
#  20                                     A
#  21                                     A
#  22                                     A
#  23                                     A
#  24                                     A
#  25                                   NaN
#  26                                   NaN
#  27                                   NaN
#  28                                   NaN
#  29                                   NaN
#
#     Third-placed teamsqualify from groups.1  \
#  0                                      NaN
#  1                                      NaN
#  2                                      NaN
#  3                                      NaN
#  4                                      NaN
#  5                                      NaN
#  6                                      NaN
#  7                                      NaN
#  8                                      NaN
#  9                                      NaN
#  10                                     NaN
#  11                                     NaN
#  12                                     NaN
#  13                                     NaN
#  14                                     NaN
#  15                                       B
#  16                                       B
#  17                                       B
#  18                                       B
#  19                                       B
#  20                                       B
#  21                                     NaN
#  22                                     NaN
#  23                                     NaN
#  24                                     NaN
#  25                                       B
#  26                                       B
#  27                                       B
#  28                                       B
#  29                                     NaN
#
#     Third-placed teamsqualify from groups.2  \
#  0                                      NaN
#  1                                      NaN
#  2                                      NaN
#  3                                      NaN
#  4                                      NaN
#  5                                      NaN
#  6                                      NaN
#  7                                      NaN
#  8                                      NaN
#  9                                      NaN
#  10                                     NaN
#  11                                     NaN
#  12                                     NaN
#  13                                     NaN
#  14                                     NaN
#  15                                       C
#  16                                       C
#  17                                       C
#  18                                     NaN
#  19                                     NaN
#  20                                     NaN
#  21                                       C
#  22                                       C
#  23                                       C
#  24                                     NaN
#  25                                       C
#  26                                       C
#  27                                       C
#  28                                     NaN
#  29                                       C
#
#     Third-placed teamsqualify from groups.3  \
#  0                                      NaN
#  1                                      NaN
#  2                                      NaN
#  3                                      NaN
#  4                                      NaN
#  5                                      NaN
#  6                                      NaN
#  7                                      NaN
#  8                                      NaN
#  9                                      NaN
#  10                                     NaN
#  11                                     NaN
#  12                                     NaN
#  13                                     NaN
#  14                                     NaN
#  15                                       D
#  16                                     NaN
#  17                                     NaN
#  18                                       D
#  19                                       D
#  20                                     NaN
#  21                                       D
#  22                                       D
#  23                                     NaN
#  24                                       D
#  25                                       D
#  26                                       D
#  27                                     NaN
#  28                                       D
#  29                                       D
#
#     Third-placed teamsqualify from groups.4  \
#  0                                      NaN
#  1                                      NaN
#  2                                      NaN
#  3                                      NaN
#  4                                      NaN
#  5                                      NaN
#  6                                      NaN
#  7                                      NaN
#  8                                      NaN
#  9                                      NaN
#  10                                     NaN
#  11                                     NaN
#  12                                     NaN
#  13                                     NaN
#  14                                     NaN
#  15                                     NaN
#  16                                       E
#  17                                     NaN
#  18                                       E
#  19                                     NaN
#  20                                       E
#  21                                       E
#  22                                     NaN
#  23                                       E
#  24                                       E
#  25                                       E
#  26                                     NaN
#  27                                       E
#  28                                       E
#  29                                       E
#
#     Third-placed teamsqualify from groups.5 Unnamed: 6 1Avs 1Bvs 1Cvs  1Dvs
#  0                                      NaN        NaN  NaN  NaN  NaN   NaN
#  1                                      NaN        NaN  NaN  NaN  NaN   NaN
#  2                                      NaN        NaN  NaN  NaN  NaN   NaN
#  3                                      NaN        NaN  NaN  NaN  NaN   NaN
#  4                                      NaN        NaN  NaN  NaN  NaN   NaN
#  5                                      NaN        NaN  NaN  NaN  NaN   NaN
#  6                                      NaN        NaN  NaN  NaN  NaN   NaN
#  7                                      NaN        NaN  NaN  NaN  NaN   NaN
#  8                                      NaN        NaN  NaN  NaN  NaN   NaN
#  9                                      NaN        NaN  NaN  NaN  NaN   NaN
#  10                                     NaN        NaN  NaN  NaN  NaN   NaN
#  11                                     NaN        NaN  NaN  NaN  NaN   NaN
#  12                                     NaN        NaN  NaN  NaN  NaN   NaN
#  13                                     NaN        NaN  NaN  NaN  NaN   NaN
#  14                                     NaN        NaN  NaN  NaN  NaN   NaN
#  15                                     NaN         3C   3D   3A   3B   NaN
#  16                                     NaN         3C   3A   3B   3E   NaN
#  17                                       F         3C   3A   3B   3F   NaN
#  18                                     NaN         3D   3A   3B   3E   NaN
#  19                                       F         3D   3A   3B   3F   NaN
#  20                                       F         3E   3A   3B   3F   NaN
#  21                                     NaN         3C   3D   3A   3E   NaN
#  22                                       F         3C   3D   3A   3F   NaN
#  23                                       F         3C   3A   3F   3E   NaN
#  24                                       F         3D   3A   3F   3E   NaN
#  25                                     NaN         3C   3D   3B   3E   NaN
#  26                                       F         3C   3D   3B   3F   NaN
#  27                                       F         3E   3C   3B   3F   NaN
#  28                                       F         3E   3D   3B   3F   NaN
#  29                                       F         3C   3D   3F   3E   NaN  ,
#     Winner SF1   v  Winner SF2
#  0         NaN NaN         NaN,
#    vte2023 Africa Cup of Nations  \
#  0                        Stages
#  1           General information
#
#                       vte2023 Africa Cup of Nations.1
#  0  Group stage Group A Group B Group C Group D Gr...
#  1                    Qualification Squads Statistics  ,
#                vte2023 Africa Cup of Nations stadiums  \
#  0  Alassane Ouattara Stadium (Abidjan) Felix Houp...
#
#              vte2023 Africa Cup of Nations stadiums.1
#  0  Alassane Ouattara Stadium (Abidjan) Felix Houp...  ,
#                              vteAfrica Cup of Nations  \
#  0                                           Editions
#  1                                      Qualification
#  2                                             Finals
#  3                                               Bids
#  4                                             Squads
#  5                                         Statistics
#  6                                      Miscellaneous
#  7  Notes: The 2021 and 2023 tournaments were actu...
#
#                            vteAfrica Cup of Nations.1
#  0  Sudan 1957 United Arab Republic 1959 Ethiopia ...
#  1  1957 1959 1962 1963 1965 1968 1970 1972 1974 1...
#  2  1957 1959 1962 1963 1965 1968 1970 1972 1974 1...
#  3                                               2027
#  4  1957 1959 1962 1963 1965 1968 1970 1972 1974 1...
#  5  Finals Appearances Awards Records and statisti...
#  6                                Balls Mascots Music
#  7  Notes: The 2021 and 2023 tournaments were actu...  ,
#    vte2023–24 in African football (CAF)  \
#  0                  « 2022–23 2024–25 »
#  1                     Domestic leagues
#  2                        Domestic cups
#  3                           Super cups
#  4           Regional club competitions
#  5                CAF club competitions
#  6           International competitions
#
#                vte2023–24 in African football (CAF).1
#  0                                « 2022–23 2024–25 »
#  1  Algeria Angola Benin Botswana Burkina Faso Bur...
#  2  Algeria Angola Botswana Burundi Cameroon '23 '...
#  3                       Algeria Angola Egypt Tunisia
#  4                            Arab Club Champions Cup
#  5  CAF Champions League qualifying rounds group s...
#  6                         2023 Africa Cup of Nations  ]

# %% [markdown]
# As can be seen, the Wikipedia page does not simply contain the AFCON groups/tables only.  There is other information that might not be relevant to me for this particular project.  I will show a few elements of the Wikipedia page in the cells below.

# %%
all_group_tables[12]
# Out:
#    Ivory Coast   v  Nigeria
# 0          NaN NaN      NaN

# %% [markdown]
# By observing the orignal 'all_group_tables' data that I imported from Wikipedia, I notice that the specific group table relating to the fixture "Ivory Coast	v	Nigeria" thatI found in my random search **all_group_tables[12]** is a few elements before that fixture list.  I *guesstimate* that the group will be found in the 9th element of the page, as seen below.

# %% [markdown]
# The table above is the table for group A. Another *guesstimate* shows me that Group B is foundin the 16th element of our data. I will now test this for all the 6 groups.

# %% [markdown]
# ### Modifying column names

# %%
for table_ref in range(8,50,7):
    print(table_ref)
# Out:
# 8
# 15
# 22
# 29
# 36
# 43

# %% [markdown]
# To link my table reference numbers to an actual group name, I imported the **ascii_uppercase library** as **alphabet** to assist me.

# %%
alphabet
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
fix_A =all_group_tables[9:15]
fix_B = all_group_tables[16:22]
fix_C =all_group_tables[23:29]
fix_D =all_group_tables[30:36]
fix_E =all_group_tables[37:43]
fix_F =all_group_tables[44:50]

# %%
fix_A
# Out:
# [   Ivory Coast   v  Guinea-Bissau
#  0          NaN NaN            NaN,
#     Nigeria   v  Equatorial Guinea
#  0      NaN NaN                NaN,
#     Equatorial Guinea   v  Guinea-Bissau
#  0                NaN NaN            NaN,
#     Ivory Coast   v  Nigeria
#  0          NaN NaN      NaN,
#     Equatorial Guinea   v  Ivory Coast
#  0                NaN NaN          NaN,
#     Guinea-Bissau   v  Nigeria
#  0            NaN NaN      NaN]

# %%
fix_A[0]
# Out:
#    Ivory Coast   v  Guinea-Bissau
# 0          NaN NaN            NaN

# %%
wiki = 'https://en.wikipedia.org/wiki/2023_Africa_Cup_of_Nations'
response = requests.get(wiki)
wiki_content = response.text
soup = BeautifulSoup(wiki_content, 'lxml') # lxml  parser is responsible for reading the HTML or XML content

# %%
# I used BeautifulSoup to find all HTML elements with the class 'footballbox' in the parsed HTML content and stored them in the "afcon74_games" variable. 
afcon23_games = soup.find_all('table', class_='fevent')

# %%
home = []
score = []
away = []

# Extract information from each game element in afcon74_games
    # - 'home' stores the home team name
    # - 'score' stores the match score
    # - 'away' stores the away team name
for game in afcon23_games:
    #  get_text() is used to extract the home team name, score, and away team name from the HTML element
    home.append(game.find('th', class_ = 'fhome').get_text()) 
    score.append(game.find('th', class_ = 'fscore').get_text())
    away.append(game.find('th', class_ = 'faway').get_text())

# %%
dict_afcon23 = {'home':home, 'score':score, 'away': away}

# %%
afcon23_df= pd.DataFrame(dict_afcon23)

# %%
afcon23_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   home    37 non-null     object
#  1   score   37 non-null     object
#  2   away    37 non-null     object
# dtypes: object(3)
# memory usage: 1016.0+ bytes

# %%
import pandas as pd

# Assuming afcon23_df contains your existing fixture data
# afcon23_df = ...

# DataFrame with knockout round fixtures
afcon23_df_KO = pd.DataFrame([['1D', "", '3BEF'], ['2A', "", '2C'], ['1A', "", '3CDE'], ['2B', "", '2F'], ['1B', "", '3ACD'], 
                              ['1C', "", '3ABF'], ['1E', "", '2D'], ['1F', "", '2E']],
                             columns=['home', 'score', 'away'])

# Concatenate the two DataFrames
afcon23_df = pd.concat([afcon23_df, afcon23_df_KO], ignore_index=True)

# Now afcon23_df contains both the existing fixtures and the knockout round fixtures

# %%
afcon23_df
# Out:
#                   home score                away
# 0         Ivory Coast      v       Guinea-Bissau
# 1             Nigeria      v   Equatorial Guinea
# 2   Equatorial Guinea      v       Guinea-Bissau
# 3         Ivory Coast      v             Nigeria
# 4   Equatorial Guinea      v         Ivory Coast
# 5       Guinea-Bissau      v             Nigeria
# 6               Egypt      v          Mozambique
# 7               Ghana      v          Cape Verde
# 8               Egypt      v               Ghana
# 9          Cape Verde      v          Mozambique
# 10         Mozambique      v               Ghana
# 11         Cape Verde      v               Egypt
# 12            Senegal      v              Gambia
# 13           Cameroon      v              Guinea
# 14            Senegal      v            Cameroon
# 15             Guinea      v              Gambia
# 16             Guinea      v             Senegal
# 17             Gambia      v            Cameroon
# 18            Algeria      v              Angola
# 19       Burkina Faso      v          Mauritania
# 20            Algeria      v        Burkina Faso
# 21         Mauritania      v              Angola
# 22             Angola      v        Burkina Faso
# 23         Mauritania      v             Algeria
# 24            Tunisia      v             Namibia
# 25               Mali      v        South Africa
# 26            Tunisia      v                Mali
# 27       South Africa      v             Namibia
# 28       South Africa      v             Tunisia
# 29            Namibia      v                Mali
# 30            Morocco      v            Tanzania
# 31           DR Congo      v              Zambia
# 32            Morocco      v            DR Congo
# 33             Zambia      v            Tanzania
# 34           Tanzania      v            DR Congo
# 35             Zambia      v             Morocco
# 36          Winner SF1     v          Winner SF2
# 37                  1D                      3BEF
# 38                  2A                        2C
# 39                  1D                      3BEF
# 40                  2A                        2C
# 41                  1A                      3CDE
# 42                  2B                        2F
# 43                  1B                      3ACD
# 44                  1C                      3ABF
# 45                  1E                        2D
# 46                  1F                        2E

# %%
afcon23_df = afcon23_df.drop([37, 38])

# %%
afcon23_df
# Out:
#                   home score                away
# 0         Ivory Coast      v       Guinea-Bissau
# 1             Nigeria      v   Equatorial Guinea
# 2   Equatorial Guinea      v       Guinea-Bissau
# 3         Ivory Coast      v             Nigeria
# 4   Equatorial Guinea      v         Ivory Coast
# 5       Guinea-Bissau      v             Nigeria
# 6               Egypt      v          Mozambique
# 7               Ghana      v          Cape Verde
# 8               Egypt      v               Ghana
# 9          Cape Verde      v          Mozambique
# 10         Mozambique      v               Ghana
# 11         Cape Verde      v               Egypt
# 12            Senegal      v              Gambia
# 13           Cameroon      v              Guinea
# 14            Senegal      v            Cameroon
# 15             Guinea      v              Gambia
# 16             Guinea      v             Senegal
# 17             Gambia      v            Cameroon
# 18            Algeria      v              Angola
# 19       Burkina Faso      v          Mauritania
# 20            Algeria      v        Burkina Faso
# 21         Mauritania      v              Angola
# 22             Angola      v        Burkina Faso
# 23         Mauritania      v             Algeria
# 24            Tunisia      v             Namibia
# 25               Mali      v        South Africa
# 26            Tunisia      v                Mali
# 27       South Africa      v             Namibia
# 28       South Africa      v             Tunisia
# 29            Namibia      v                Mali
# 30            Morocco      v            Tanzania
# 31           DR Congo      v              Zambia
# 32            Morocco      v            DR Congo
# 33             Zambia      v            Tanzania
# 34           Tanzania      v            DR Congo
# 35             Zambia      v             Morocco
# 36          Winner SF1     v          Winner SF2
# 39                  1D                      3BEF
# 40                  2A                        2C
# 41                  1A                      3CDE
# 42                  2B                        2F
# 43                  1B                      3ACD
# 44                  1C                      3ABF
# 45                  1E                        2D
# 46                  1F                        2E

# %%
afcon23_df['Stage'] = "KO"
afcon23_df
# Out:
#                   home score                away Stage
# 0         Ivory Coast      v       Guinea-Bissau    KO
# 1             Nigeria      v   Equatorial Guinea    KO
# 2   Equatorial Guinea      v       Guinea-Bissau    KO
# 3         Ivory Coast      v             Nigeria    KO
# 4   Equatorial Guinea      v         Ivory Coast    KO
# 5       Guinea-Bissau      v             Nigeria    KO
# 6               Egypt      v          Mozambique    KO
# 7               Ghana      v          Cape Verde    KO
# 8               Egypt      v               Ghana    KO
# 9          Cape Verde      v          Mozambique    KO
# 10         Mozambique      v               Ghana    KO
# 11         Cape Verde      v               Egypt    KO
# 12            Senegal      v              Gambia    KO
# 13           Cameroon      v              Guinea    KO
# 14            Senegal      v            Cameroon    KO
# 15             Guinea      v              Gambia    KO
# 16             Guinea      v             Senegal    KO
# 17             Gambia      v            Cameroon    KO
# 18            Algeria      v              Angola    KO
# 19       Burkina Faso      v          Mauritania    KO
# 20            Algeria      v        Burkina Faso    KO
# 21         Mauritania      v              Angola    KO
# 22             Angola      v        Burkina Faso    KO
# 23         Mauritania      v             Algeria    KO
# 24            Tunisia      v             Namibia    KO
# 25               Mali      v        South Africa    KO
# 26            Tunisia      v                Mali    KO
# 27       South Africa      v             Namibia    KO
# 28       South Africa      v             Tunisia    KO
# 29            Namibia      v                Mali    KO
# 30            Morocco      v            Tanzania    KO
# 31           DR Congo      v              Zambia    KO
# 32            Morocco      v            DR Congo    KO
# 33             Zambia      v            Tanzania    KO
# 34           Tanzania      v            DR Congo    KO
# 35             Zambia      v             Morocco    KO
# 36          Winner SF1     v          Winner SF2    KO
# 39                  1D                      3BEF    KO
# 40                  2A                        2C    KO
# 41                  1A                      3CDE    KO
# 42                  2B                        2F    KO
# 43                  1B                      3ACD    KO
# 44                  1C                      3ABF    KO
# 45                  1E                        2D    KO
# 46                  1F                        2E    KO

# %%
afcon23_df.loc[:37, 'stage'] = 'Group'
afcon23_df
# Out:
#                   home score                away Stage  stage
# 0         Ivory Coast      v       Guinea-Bissau    KO  Group
# 1             Nigeria      v   Equatorial Guinea    KO  Group
# 2   Equatorial Guinea      v       Guinea-Bissau    KO  Group
# 3         Ivory Coast      v             Nigeria    KO  Group
# 4   Equatorial Guinea      v         Ivory Coast    KO  Group
# 5       Guinea-Bissau      v             Nigeria    KO  Group
# 6               Egypt      v          Mozambique    KO  Group
# 7               Ghana      v          Cape Verde    KO  Group
# 8               Egypt      v               Ghana    KO  Group
# 9          Cape Verde      v          Mozambique    KO  Group
# 10         Mozambique      v               Ghana    KO  Group
# 11         Cape Verde      v               Egypt    KO  Group
# 12            Senegal      v              Gambia    KO  Group
# 13           Cameroon      v              Guinea    KO  Group
# 14            Senegal      v            Cameroon    KO  Group
# 15             Guinea      v              Gambia    KO  Group
# 16             Guinea      v             Senegal    KO  Group
# 17             Gambia      v            Cameroon    KO  Group
# 18            Algeria      v              Angola    KO  Group
# 19       Burkina Faso      v          Mauritania    KO  Group
# 20            Algeria      v        Burkina Faso    KO  Group
# 21         Mauritania      v              Angola    KO  Group
# 22             Angola      v        Burkina Faso    KO  Group
# 23         Mauritania      v             Algeria    KO  Group
# 24            Tunisia      v             Namibia    KO  Group
# 25               Mali      v        South Africa    KO  Group
# 26            Tunisia      v                Mali    KO  Group
# 27       South Africa      v             Namibia    KO  Group
# 28       South Africa      v             Tunisia    KO  Group
# 29            Namibia      v                Mali    KO  Group
# 30            Morocco      v            Tanzania    KO  Group
# 31           DR Congo      v              Zambia    KO  Group
# 32            Morocco      v            DR Congo    KO  Group
# 33             Zambia      v            Tanzania    KO  Group
# 34           Tanzania      v            DR Congo    KO  Group
# 35             Zambia      v             Morocco    KO  Group
# 36          Winner SF1     v          Winner SF2    KO  Group
# 39                  1D                      3BEF    KO    NaN
# 40                  2A                        2C    KO    NaN
# 41                  1A                      3CDE    KO    NaN
# 42                  2B                        2F    KO    NaN
# 43                  1B                      3ACD    KO    NaN
# 44                  1C                      3ABF    KO    NaN
# 45                  1E                        2D    KO    NaN
# 46                  1F                        2E    KO    NaN

# %%
afcon23_df.loc[39:46, 'stage'] = 'L16'
afcon23_df
# Out:
#                   home score                away Stage  stage
# 0         Ivory Coast      v       Guinea-Bissau    KO  Group
# 1             Nigeria      v   Equatorial Guinea    KO  Group
# 2   Equatorial Guinea      v       Guinea-Bissau    KO  Group
# 3         Ivory Coast      v             Nigeria    KO  Group
# 4   Equatorial Guinea      v         Ivory Coast    KO  Group
# 5       Guinea-Bissau      v             Nigeria    KO  Group
# 6               Egypt      v          Mozambique    KO  Group
# 7               Ghana      v          Cape Verde    KO  Group
# 8               Egypt      v               Ghana    KO  Group
# 9          Cape Verde      v          Mozambique    KO  Group
# 10         Mozambique      v               Ghana    KO  Group
# 11         Cape Verde      v               Egypt    KO  Group
# 12            Senegal      v              Gambia    KO  Group
# 13           Cameroon      v              Guinea    KO  Group
# 14            Senegal      v            Cameroon    KO  Group
# 15             Guinea      v              Gambia    KO  Group
# 16             Guinea      v             Senegal    KO  Group
# 17             Gambia      v            Cameroon    KO  Group
# 18            Algeria      v              Angola    KO  Group
# 19       Burkina Faso      v          Mauritania    KO  Group
# 20            Algeria      v        Burkina Faso    KO  Group
# 21         Mauritania      v              Angola    KO  Group
# 22             Angola      v        Burkina Faso    KO  Group
# 23         Mauritania      v             Algeria    KO  Group
# 24            Tunisia      v             Namibia    KO  Group
# 25               Mali      v        South Africa    KO  Group
# 26            Tunisia      v                Mali    KO  Group
# 27       South Africa      v             Namibia    KO  Group
# 28       South Africa      v             Tunisia    KO  Group
# 29            Namibia      v                Mali    KO  Group
# 30            Morocco      v            Tanzania    KO  Group
# 31           DR Congo      v              Zambia    KO  Group
# 32            Morocco      v            DR Congo    KO  Group
# 33             Zambia      v            Tanzania    KO  Group
# 34           Tanzania      v            DR Congo    KO  Group
# 35             Zambia      v             Morocco    KO  Group
# 36          Winner SF1     v          Winner SF2    KO  Group
# 39                  1D                      3BEF    KO    L16
# 40                  2A                        2C    KO    L16
# 41                  1A                      3CDE    KO    L16
# 42                  2B                        2F    KO    L16
# 43                  1B                      3ACD    KO    L16
# 44                  1C                      3ABF    KO    L16
# 45                  1E                        2D    KO    L16
# 46                  1F                        2E    KO    L16

# %%
afcon23_df['ko_label'] = ''
afcon23_df
# Out:
#                   home score                away Stage  stage ko_label
# 0         Ivory Coast      v       Guinea-Bissau    KO  Group
# 1             Nigeria      v   Equatorial Guinea    KO  Group
# 2   Equatorial Guinea      v       Guinea-Bissau    KO  Group
# 3         Ivory Coast      v             Nigeria    KO  Group
# 4   Equatorial Guinea      v         Ivory Coast    KO  Group
# 5       Guinea-Bissau      v             Nigeria    KO  Group
# 6               Egypt      v          Mozambique    KO  Group
# 7               Ghana      v          Cape Verde    KO  Group
# 8               Egypt      v               Ghana    KO  Group
# 9          Cape Verde      v          Mozambique    KO  Group
# 10         Mozambique      v               Ghana    KO  Group
# 11         Cape Verde      v               Egypt    KO  Group
# 12            Senegal      v              Gambia    KO  Group
# 13           Cameroon      v              Guinea    KO  Group
# 14            Senegal      v            Cameroon    KO  Group
# 15             Guinea      v              Gambia    KO  Group
# 16             Guinea      v             Senegal    KO  Group
# 17             Gambia      v            Cameroon    KO  Group
# 18            Algeria      v              Angola    KO  Group
# 19       Burkina Faso      v          Mauritania    KO  Group
# 20            Algeria      v        Burkina Faso    KO  Group
# 21         Mauritania      v              Angola    KO  Group
# 22             Angola      v        Burkina Faso    KO  Group
# 23         Mauritania      v             Algeria    KO  Group
# 24            Tunisia      v             Namibia    KO  Group
# 25               Mali      v        South Africa    KO  Group
# 26            Tunisia      v                Mali    KO  Group
# 27       South Africa      v             Namibia    KO  Group
# 28       South Africa      v             Tunisia    KO  Group
# 29            Namibia      v                Mali    KO  Group
# 30            Morocco      v            Tanzania    KO  Group
# 31           DR Congo      v              Zambia    KO  Group
# 32            Morocco      v            DR Congo    KO  Group
# 33             Zambia      v            Tanzania    KO  Group
# 34           Tanzania      v            DR Congo    KO  Group
# 35             Zambia      v             Morocco    KO  Group
# 36          Winner SF1     v          Winner SF2    KO  Group
# 39                  1D                      3BEF    KO    L16
# 40                  2A                        2C    KO    L16
# 41                  1A                      3CDE    KO    L16
# 42                  2B                        2F    KO    L16
# 43                  1B                      3ACD    KO    L16
# 44                  1C                      3ABF    KO    L16
# 45                  1E                        2D    KO    L16
# 46                  1F                        2E    KO    L16

# %%
afcon23_df = afcon23_df.drop(36)
afcon23_df
# Out:
#                   home score                away Stage  stage ko_label
# 0         Ivory Coast      v       Guinea-Bissau    KO  Group
# 1             Nigeria      v   Equatorial Guinea    KO  Group
# 2   Equatorial Guinea      v       Guinea-Bissau    KO  Group
# 3         Ivory Coast      v             Nigeria    KO  Group
# 4   Equatorial Guinea      v         Ivory Coast    KO  Group
# 5       Guinea-Bissau      v             Nigeria    KO  Group
# 6               Egypt      v          Mozambique    KO  Group
# 7               Ghana      v          Cape Verde    KO  Group
# 8               Egypt      v               Ghana    KO  Group
# 9          Cape Verde      v          Mozambique    KO  Group
# 10         Mozambique      v               Ghana    KO  Group
# 11         Cape Verde      v               Egypt    KO  Group
# 12            Senegal      v              Gambia    KO  Group
# 13           Cameroon      v              Guinea    KO  Group
# 14            Senegal      v            Cameroon    KO  Group
# 15             Guinea      v              Gambia    KO  Group
# 16             Guinea      v             Senegal    KO  Group
# 17             Gambia      v            Cameroon    KO  Group
# 18            Algeria      v              Angola    KO  Group
# 19       Burkina Faso      v          Mauritania    KO  Group
# 20            Algeria      v        Burkina Faso    KO  Group
# 21         Mauritania      v              Angola    KO  Group
# 22             Angola      v        Burkina Faso    KO  Group
# 23         Mauritania      v             Algeria    KO  Group
# 24            Tunisia      v             Namibia    KO  Group
# 25               Mali      v        South Africa    KO  Group
# 26            Tunisia      v                Mali    KO  Group
# 27       South Africa      v             Namibia    KO  Group
# 28       South Africa      v             Tunisia    KO  Group
# 29            Namibia      v                Mali    KO  Group
# 30            Morocco      v            Tanzania    KO  Group
# 31           DR Congo      v              Zambia    KO  Group
# 32            Morocco      v            DR Congo    KO  Group
# 33             Zambia      v            Tanzania    KO  Group
# 34           Tanzania      v            DR Congo    KO  Group
# 35             Zambia      v             Morocco    KO  Group
# 39                  1D                      3BEF    KO    L16
# 40                  2A                        2C    KO    L16
# 41                  1A                      3CDE    KO    L16
# 42                  2B                        2F    KO    L16
# 43                  1B                      3ACD    KO    L16
# 44                  1C                      3ABF    KO    L16
# 45                  1E                        2D    KO    L16
# 46                  1F                        2E    KO    L16

# %%
# Assuming df is your DataFrame
afcon23_df.to_csv('afcon23_fixtures_group_L16.csv', index=False)
